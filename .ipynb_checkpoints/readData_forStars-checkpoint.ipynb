# %%
from astropy.io import fits
from astropy.table import Table
import numpy as np
import matplotlib.pylab as plt 
import matplotlib.lines as mlines
from matplotlib.legend import Legend
from pythonds.basic.stack import Stack
from math import *
from sklearn.neighbors import KDTree
from lrg_plot_functions import *
from lrg_sum_functions import *
from cosmo_Calc import *
from divideByTwo import *
# from read_data import *
from nearNeighbors import *
from scipy import stats
from astropy import stats
import healpy as hp
from localBKG_and_interlopersHEALPix import *
# import healpy as hpy
from makeCutoutTableFunc import *
from plotHistogramProjections3D import *
from read_bricks import *
from mpl_toolkits.axes_grid1 import make_axes_locatable
import random

# %%
def read_data_new(DECaLS_data):
    
   # Read in data from DECaLS bricks

    # source type
    source_type = []
    source_type = DECaLS_data.field('type')

    # RA
    ra = []
    ra = DECaLS_data.field('ra')

    # Dec
    dec = []
    dec = DECaLS_data.field('dec')

    # ref_cat
    ref_cat = []
    ref_cat = DECaLS_data.field('ref_cat')
    
    # gaia g-band mag
    gaia_phot_g_mean_mag = []
    gaia_phot_g_mean_mag = DECaLS_data.field('gaia_phot_g_mean_mag')

    
    return source_type, ra, dec, ref_cat, gaia_phot_g_mean_mag

# %%
hdu_sweep1 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/sweep-000m005-010p000.fits') # this is one sweep file of the DECaLS data
hdu_sweep2 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/sweep-000m010-010m005.fits') # this is one sweep file of the DECaLS data
hdu_sweep3 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/sweep-000m015-010m010.fits') 
hdu_sweep4 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/sweep-000p000-010p005.fits')
hdu_sweep5 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/sweep-000p005-010p010.fits')

hdu_sweep6 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/sweep-010m005-020p000.fits')
hdu_sweep7 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/sweep-010m010-020m005.fits')
hdu_sweep8 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/sweep-010m015-020m010.fits')
hdu_sweep9 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/sweep-010p000-020p005.fits')
hdu_sweep10 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/sweep-010p005-020p010.fits')

hdu_sweep11 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/sweep-020m005-030p000.fits') 
hdu_sweep12 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/sweep-020m010-030m005.fits')
hdu_sweep13 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/sweep-020m015-030m010.fits') 
hdu_sweep14 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/sweep-020p000-030p005.fits')
hdu_sweep15 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/sweep-020p005-030p010.fits')

hdu_sweep16 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/sweep-030m005-040p000.fits') 
hdu_sweep17 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/sweep-030m010-040m005.fits') 
hdu_sweep18 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/sweep-030m015-040m010.fits')
hdu_sweep19 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/sweep-030p000-040p005.fits') 
hdu_sweep20 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/sweep-030p005-040p010.fits')

# hdu_sweep21 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/')
# hdu_sweep22 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/') 
# hdu_sweep23 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/') 
# hdu_sweep24 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/')
# hdu_sweep25 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/') 

# hdu_sweep26 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/') 
# hdu_sweep27 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/')
# hdu_sweep28 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/')
# hdu_sweep29 = fits.open('/Users/mtownsend/documents/LRG_Data/expanded-data/star_data/')

# %%
DECaLS_data1 = hdu_sweep1[1].data
print('done')
DECaLS_data2 = hdu_sweep2[1].data
print('done')
DECaLS_data3 = hdu_sweep3[1].data
print('done')
DECaLS_data4 = hdu_sweep4[1].data
print('done')
DECaLS_data5 = hdu_sweep5[1].data
print('done')
DECaLS_data6 = hdu_sweep6[1].data
print('done')
DECaLS_data7 = hdu_sweep7[1].data
print('done')
DECaLS_data8 = hdu_sweep8[1].data
print('done')
DECaLS_data9 = hdu_sweep9[1].data
print('done')
DECaLS_data10 = hdu_sweep10[1].data
print('done')
DECaLS_data11 = hdu_sweep11[1].data
print('done')
DECaLS_data12 = hdu_sweep12[1].data
print('done')
DECaLS_data13 = hdu_sweep13[1].data
print('done')
DECaLS_data14 = hdu_sweep14[1].data
print('done')
DECaLS_data15 = hdu_sweep15[1].data
print('done')
DECaLS_data16 = hdu_sweep16[1].data
print('done')
DECaLS_data17 = hdu_sweep17[1].data
print('done')
DECaLS_data18 = hdu_sweep18[1].data
print('done')
DECaLS_data19 = hdu_sweep19[1].data
print('done')
DECaLS_data20 = hdu_sweep20[1].data
print('done')
# DECaLS_data21 = hdu_sweep21[1].data
# print('done')
# DECaLS_data22 = hdu_sweep22[1].data
# print('done')
# DECaLS_data23 = hdu_sweep23[1].data
# print('done')
# DECaLS_data24 = hdu_sweep24[1].data
# print('done')
# DECaLS_data25 = hdu_sweep25[1].data
# print('done')
# DECaLS_data26 = hdu_sweep26[1].data
# print('done')
# DECaLS_data27 = hdu_sweep27[1].data
# print('done')
# DECaLS_data28 = hdu_sweep28[1].data
# print('done')
# DECaLS_data29 = hdu_sweep29[1].data
# print('done')
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done

# %%
DECaLS_data = np.array([DECaLS_data1, 
DECaLS_data2,
DECaLS_data3, 
DECaLS_data4,
DECaLS_data5,
DECaLS_data6, 
DECaLS_data7,
DECaLS_data8,
DECaLS_data9,
DECaLS_data10,
DECaLS_data11,
DECaLS_data12,
DECaLS_data13,
DECaLS_data14, 
DECaLS_data15,
DECaLS_data16,
DECaLS_data17, 
DECaLS_data18,
DECaLS_data19,
DECaLS_data20]) #,
# DECaLS_data21,
# DECaLS_data22,
# DECaLS_data23,
# DECaLS_data24,
# DECaLS_data25,
# DECaLS_data26,
# DECaLS_data27,
# DECaLS_data28,
# DECaLS_data29])

# %%
for i in range(len(DECaLS_data)):
    source_type, ra, dec, ref_cat, gaia_phot_g_mean_mag = read_data_new(DECaLS_data[i])
    np.savez('/Users/mtownsend/Documents/LRG_Data/expanded-data/star-cats/0to40/ra_STAR-0-40-dr9-{}.npz'.format(i), ra=ra)
    np.savez('/Users/mtownsend/Documents/LRG_Data/expanded-data/star-cats/0to40/dec_STAR-0-40-dr9-{}.npz'.format(i), dec=dec)    
    np.savez('/Users/mtownsend/Documents/LRG_Data/expanded-data/star-cats/0to40/source-type_STAR-0-40-dr9-{}.npz'.format(i), source_type=source_type)
    np.savez('/Users/mtownsend/Documents/LRG_Data/expanded-data/star-cats/0to40/ref-cat_STAR-0-40-dr9-{}.npz'.format(i), ref_cat=ref_cat)
    np.savez('/Users/mtownsend/Documents/LRG_Data/expanded-data/star-cats/0to40/gaia-gmag_STAR-0-40-dr9-{}.npz'.format(i), gaia_phot_g_mean_mag=gaia_phot_g_mean_mag)
    
    
    print('end saving files ', i)
# Out:
# end saving files  0
# end saving files  1
# end saving files  2
# end saving files  3
# end saving files  4
# end saving files  5
# end saving files  6
# end saving files  7
# end saving files  8
# end saving files  9
# end saving files  10
# end saving files  11
# end saving files  12
# end saving files  13
# end saving files  14
# end saving files  15
# end saving files  16
# end saving files  17
# end saving files  18
# end saving files  19

# %%
dataTOT = []
for i in range(20):
    filename = "/Users/mtownsend/Documents/LRG_Data/expanded-data/star-cats/0to40/gaia-gmag_STAR-0-40-dr9-{}.npz".format(i)
    array = 'gaia_phot_g_mean_mag'
    data = np.load(filename)
    dataTOT.append(data[array])
    

print(len(dataTOT))
# Out:
# 20

# %%
dataTOTAL = np.concatenate([dataTOT[0], dataTOT[1], dataTOT[2], dataTOT[3], dataTOT[4],
        dataTOT[5], dataTOT[6], dataTOT[7], dataTOT[8], 
        dataTOT[9], dataTOT[10], dataTOT[11], dataTOT[12], 
        dataTOT[13], dataTOT[14], dataTOT[15], dataTOT[16], 
        dataTOT[17], dataTOT[18], dataTOT[19]]) #, dataTOT[20],
#         dataTOT[21], dataTOT[22], dataTOT[23], dataTOT[24],
#         dataTOT[25], dataTOT[26], dataTOT[27], dataTOT[28]])

print(len(dataTOTAL))

# Save the new npz file
np.savez('/Users/mtownsend/Documents/LRG_Data/expanded-data/star-cats/gaia-gmag_STAR-0-40-dr9.npz', dataTOTAL)
# Out:
# 114461206
