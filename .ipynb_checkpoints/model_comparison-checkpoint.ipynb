# %%
from astropy.io import fits
from astropy.table import Table
import numpy as np
import matplotlib.pylab as plt 
import matplotlib.lines as mlines
from matplotlib.legend import Legend
from pythonds.basic.stack import Stack
from math import *
from sklearn.neighbors import KDTree
from lrg_plot_functions import *
from lrg_sum_functions import *
from cosmo_Calc import *
from divideByTwo import *
from read_data import *
from nearNeighbors import *
from scipy import stats
from astropy import stats
import healpy as hp
from localBKG_and_interlopersHEALPix import *
# import healpy as hpy
from makeCutoutTableFunc import *
from plotHistogramProjections3D import *
from read_bricks import *
from mpl_toolkits.axes_grid1 import make_axes_locatable
import random

# %% [markdown]
# Notes on what to modify:
#
# Instead of reading in "masked_null" results, read in /Users/mtownsend/Documents/LRG_Data/new_null_<bin>_<zlimit>.npz
# These are results where satellites are added *after* masks are applied to null results.
#
# Still need to apply masks to real results, as the only saved copies of those I have are unmasked.

# %%
# read in masked null results with random satellites added

# lowz bins

low_null25 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_low_25.npz')
low_null25_1 = low_null25['new_low_null_25_1']
low_null25_2 = low_null25['new_low_null_25_2']
low_null25_3 = low_null25['new_low_null_25_3']
low_null25_4 = low_null25['new_low_null_25_4']
low_null25_5 = low_null25['new_low_null_25_5']
low_null25_6 = low_null25['new_low_null_25_6']
low_null25_7 = low_null25['new_low_null_25_7']
low_null25_8 = low_null25['new_low_null_25_8']

low_null03 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_low_03.npz')
low_null03_1 = low_null03['new_low_null_03_1']
low_null03_2 = low_null03['new_low_null_03_2']
low_null03_3 = low_null03['new_low_null_03_3']
low_null03_4 = low_null03['new_low_null_03_4']
low_null03_5 = low_null03['new_low_null_03_5']
low_null03_6 = low_null03['new_low_null_03_6']
low_null03_7 = low_null03['new_low_null_03_7']
low_null03_8 = low_null03['new_low_null_03_8']

# %%
# read in masked null results with random satellites added

# mid1 bins

mid1_null25 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_mid1_25.npz')
mid1_null25_1 = mid1_null25['new_mid1_null_25_1']
mid1_null25_2 = mid1_null25['new_mid1_null_25_2']
mid1_null25_3 = mid1_null25['new_mid1_null_25_3']
mid1_null25_4 = mid1_null25['new_mid1_null_25_4']
mid1_null25_5 = mid1_null25['new_mid1_null_25_5']
mid1_null25_6 = mid1_null25['new_mid1_null_25_6']
mid1_null25_7 = mid1_null25['new_mid1_null_25_7']
mid1_null25_8 = mid1_null25['new_mid1_null_25_8']


mid1_null03 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_mid1_03.npz')
mid1_null03_1 = mid1_null03['new_mid1_null_03_1']
mid1_null03_2 = mid1_null03['new_mid1_null_03_2']
mid1_null03_3 = mid1_null03['new_mid1_null_03_3']
mid1_null03_4 = mid1_null03['new_mid1_null_03_4']
mid1_null03_5 = mid1_null03['new_mid1_null_03_5']
mid1_null03_6 = mid1_null03['new_mid1_null_03_6']
mid1_null03_7 = mid1_null03['new_mid1_null_03_7']
mid1_null03_8 = mid1_null03['new_mid1_null_03_8']


mid1_null35 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_mid1_35.npz')
mid1_null35_1 = mid1_null35['new_mid1_null_35_1']
mid1_null35_2 = mid1_null35['new_mid1_null_35_2']
mid1_null35_3 = mid1_null35['new_mid1_null_35_3']
mid1_null35_4 = mid1_null35['new_mid1_null_35_4']
mid1_null35_5 = mid1_null35['new_mid1_null_35_5']
mid1_null35_6 = mid1_null35['new_mid1_null_35_6']
mid1_null35_7 = mid1_null35['new_mid1_null_35_7']
mid1_null35_8 = mid1_null35['new_mid1_null_35_8']


mid1_null04 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_mid1_04.npz')
mid1_null04_1 = mid1_null04['new_mid1_null_04_1']
mid1_null04_2 = mid1_null04['new_mid1_null_04_2']
mid1_null04_3 = mid1_null04['new_mid1_null_04_3']
mid1_null04_4 = mid1_null04['new_mid1_null_04_4']
mid1_null04_5 = mid1_null04['new_mid1_null_04_5']
mid1_null04_6 = mid1_null04['new_mid1_null_04_6']
mid1_null04_7 = mid1_null04['new_mid1_null_04_7']
mid1_null04_8 = mid1_null04['new_mid1_null_04_8']

# %%
# read in masked null results with random satellites added

# mid2 bins

mid2_null25 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_mid2_25.npz')
mid2_null25_1 = mid2_null25['new_mid2_null_25_1']
mid2_null25_2 = mid2_null25['new_mid2_null_25_2']
mid2_null25_3 = mid2_null25['new_mid2_null_25_3']
mid2_null25_4 = mid2_null25['new_mid2_null_25_4']
mid2_null25_5 = mid2_null25['new_mid2_null_25_5']
mid2_null25_6 = mid2_null25['new_mid2_null_25_6']
mid2_null25_7 = mid2_null25['new_mid2_null_25_7']
mid2_null25_8 = mid2_null25['new_mid2_null_25_8']


mid2_null03 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_mid2_03.npz')
mid2_null03_1 = mid2_null03['new_mid2_null_03_1']
mid2_null03_2 = mid2_null03['new_mid2_null_03_2']
mid2_null03_3 = mid2_null03['new_mid2_null_03_3']
mid2_null03_4 = mid2_null03['new_mid2_null_03_4']
mid2_null03_5 = mid2_null03['new_mid2_null_03_5']
mid2_null03_6 = mid2_null03['new_mid2_null_03_6']
mid2_null03_7 = mid2_null03['new_mid2_null_03_7']
mid2_null03_8 = mid2_null03['new_mid2_null_03_8']


mid2_null35 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_mid2_35.npz')
mid2_null35_1 = mid2_null35['new_mid2_null_35_1']
mid2_null35_2 = mid2_null35['new_mid2_null_35_2']
mid2_null35_3 = mid2_null35['new_mid2_null_35_3']
mid2_null35_4 = mid2_null35['new_mid2_null_35_4']
mid2_null35_5 = mid2_null35['new_mid2_null_35_5']
mid2_null35_6 = mid2_null35['new_mid2_null_35_6']
mid2_null35_7 = mid2_null35['new_mid2_null_35_7']
mid2_null35_8 = mid2_null35['new_mid2_null_35_8']


mid2_null04 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_mid2_04.npz')
mid2_null04_1 = mid2_null04['new_mid2_null_04_1']
mid2_null04_2 = mid2_null04['new_mid2_null_04_2']
mid2_null04_3 = mid2_null04['new_mid2_null_04_3']
mid2_null04_4 = mid2_null04['new_mid2_null_04_4']
mid2_null04_5 = mid2_null04['new_mid2_null_04_5']
mid2_null04_6 = mid2_null04['new_mid2_null_04_6']
mid2_null04_7 = mid2_null04['new_mid2_null_04_7']
mid2_null04_8 = mid2_null04['new_mid2_null_04_8']


mid2_null45 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_mid2_45.npz')
mid2_null45_1 = mid2_null45['new_mid2_null_45_1']
mid2_null45_2 = mid2_null45['new_mid2_null_45_2']
mid2_null45_3 = mid2_null45['new_mid2_null_45_3']
mid2_null45_4 = mid2_null45['new_mid2_null_45_4']
mid2_null45_5 = mid2_null45['new_mid2_null_45_5']
mid2_null45_6 = mid2_null45['new_mid2_null_45_6']
mid2_null45_7 = mid2_null45['new_mid2_null_45_7']
mid2_null45_8 = mid2_null45['new_mid2_null_45_8']


mid2_null05 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_mid2_05.npz')
mid2_null05_1 = mid2_null05['new_mid2_null_05_1']
mid2_null05_2 = mid2_null05['new_mid2_null_05_2']
mid2_null05_3 = mid2_null05['new_mid2_null_05_3']
mid2_null05_4 = mid2_null05['new_mid2_null_05_4']
mid2_null05_5 = mid2_null05['new_mid2_null_05_5']
mid2_null05_6 = mid2_null05['new_mid2_null_05_6']
mid2_null05_7 = mid2_null05['new_mid2_null_05_7']
mid2_null05_8 = mid2_null05['new_mid2_null_05_8']

# %%
# read in masked null results with random satellites added

# mid3 bins

mid3_null25 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_mid3_25.npz')
mid3_null25_1 = mid3_null25['new_mid3_null_25_1']
mid3_null25_2 = mid3_null25['new_mid3_null_25_2']
mid3_null25_3 = mid3_null25['new_mid3_null_25_3']
mid3_null25_4 = mid3_null25['new_mid3_null_25_4']
mid3_null25_5 = mid3_null25['new_mid3_null_25_5']
mid3_null25_6 = mid3_null25['new_mid3_null_25_6']
mid3_null25_7 = mid3_null25['new_mid3_null_25_7']
mid3_null25_8 = mid3_null25['new_mid3_null_25_8']


mid3_null03 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_mid3_03.npz')
mid3_null03_1 = mid3_null03['new_mid3_null_03_1']
mid3_null03_2 = mid3_null03['new_mid3_null_03_2']
mid3_null03_3 = mid3_null03['new_mid3_null_03_3']
mid3_null03_4 = mid3_null03['new_mid3_null_03_4']
mid3_null03_5 = mid3_null03['new_mid3_null_03_5']
mid3_null03_6 = mid3_null03['new_mid3_null_03_6']
mid3_null03_7 = mid3_null03['new_mid3_null_03_7']
mid3_null03_8 = mid3_null03['new_mid3_null_03_8']


mid3_null35 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_mid3_35.npz')
mid3_null35_1 = mid3_null35['new_mid3_null_35_1']
mid3_null35_2 = mid3_null35['new_mid3_null_35_2']
mid3_null35_3 = mid3_null35['new_mid3_null_35_3']
mid3_null35_4 = mid3_null35['new_mid3_null_35_4']
mid3_null35_5 = mid3_null35['new_mid3_null_35_5']
mid3_null35_6 = mid3_null35['new_mid3_null_35_6']
mid3_null35_7 = mid3_null35['new_mid3_null_35_7']
mid3_null35_8 = mid3_null35['new_mid3_null_35_8']


mid3_null04 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_mid3_04.npz')
mid3_null04_1 = mid3_null04['new_mid3_null_04_1']
mid3_null04_2 = mid3_null04['new_mid3_null_04_2']
mid3_null04_3 = mid3_null04['new_mid3_null_04_3']
mid3_null04_4 = mid3_null04['new_mid3_null_04_4']
mid3_null04_5 = mid3_null04['new_mid3_null_04_5']
mid3_null04_6 = mid3_null04['new_mid3_null_04_6']
mid3_null04_7 = mid3_null04['new_mid3_null_04_7']
mid3_null04_8 = mid3_null04['new_mid3_null_04_8']


mid3_null45 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_mid3_45.npz')
mid3_null45_1 = mid3_null45['new_mid3_null_45_1']
mid3_null45_2 = mid3_null45['new_mid3_null_45_2']
mid3_null45_3 = mid3_null45['new_mid3_null_45_3']
mid3_null45_4 = mid3_null45['new_mid3_null_45_4']
mid3_null45_5 = mid3_null45['new_mid3_null_45_5']
mid3_null45_6 = mid3_null45['new_mid3_null_45_6']
mid3_null45_7 = mid3_null45['new_mid3_null_45_7']
mid3_null45_8 = mid3_null45['new_mid3_null_45_8']


mid3_null05 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_mid3_05.npz')
mid3_null05_1 = mid3_null05['new_mid3_null_05_1']
mid3_null05_2 = mid3_null05['new_mid3_null_05_2']
mid3_null05_3 = mid3_null05['new_mid3_null_05_3']
mid3_null05_4 = mid3_null05['new_mid3_null_05_4']
mid3_null05_5 = mid3_null05['new_mid3_null_05_5']
mid3_null05_6 = mid3_null05['new_mid3_null_05_6']
mid3_null05_7 = mid3_null05['new_mid3_null_05_7']
mid3_null05_8 = mid3_null05['new_mid3_null_05_8']


mid3_null55 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_mid3_55.npz')
mid3_null55_1 = mid3_null55['new_mid3_null_55_1']
mid3_null55_2 = mid3_null55['new_mid3_null_55_2']
mid3_null55_3 = mid3_null55['new_mid3_null_55_3']
mid3_null55_4 = mid3_null55['new_mid3_null_55_4']
mid3_null55_5 = mid3_null55['new_mid3_null_55_5']
mid3_null55_6 = mid3_null55['new_mid3_null_55_6']
mid3_null55_7 = mid3_null55['new_mid3_null_55_7']
mid3_null55_8 = mid3_null55['new_mid3_null_55_8']


mid3_null06 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_mid3_06.npz')
mid3_null06_1 = mid3_null06['new_mid3_null_06_1']
mid3_null06_2 = mid3_null06['new_mid3_null_06_2']
mid3_null06_3 = mid3_null06['new_mid3_null_06_3']
mid3_null06_4 = mid3_null06['new_mid3_null_06_4']
mid3_null06_5 = mid3_null06['new_mid3_null_06_5']
mid3_null06_6 = mid3_null06['new_mid3_null_06_6']
mid3_null06_7 = mid3_null06['new_mid3_null_06_7']
mid3_null06_8 = mid3_null06['new_mid3_null_06_8']

# %%
# read in masked null results with random satellites added

# high bins

high_null25 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_high_25.npz')
high_null25_1 = high_null25['new_high_null_25_1']
high_null25_2 = high_null25['new_high_null_25_2']
high_null25_3 = high_null25['new_high_null_25_3']
high_null25_4 = high_null25['new_high_null_25_4']
high_null25_5 = high_null25['new_high_null_25_5']
high_null25_6 = high_null25['new_high_null_25_6']
high_null25_7 = high_null25['new_high_null_25_7']
high_null25_8 = high_null25['new_high_null_25_8']


high_null03 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_high_03.npz')
high_null03_1 = high_null03['new_high_null_03_1']
high_null03_2 = high_null03['new_high_null_03_2']
high_null03_3 = high_null03['new_high_null_03_3']
high_null03_4 = high_null03['new_high_null_03_4']
high_null03_5 = high_null03['new_high_null_03_5']
high_null03_6 = high_null03['new_high_null_03_6']
high_null03_7 = high_null03['new_high_null_03_7']
high_null03_8 = high_null03['new_high_null_03_8']


high_null35 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_high_35.npz')
high_null35_1 = high_null35['new_high_null_35_1']
high_null35_2 = high_null35['new_high_null_35_2']
high_null35_3 = high_null35['new_high_null_35_3']
high_null35_4 = high_null35['new_high_null_35_4']
high_null35_5 = high_null35['new_high_null_35_5']
high_null35_6 = high_null35['new_high_null_35_6']
high_null35_7 = high_null35['new_high_null_35_7']
high_null35_8 = high_null35['new_high_null_35_8']


high_null04 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_high_04.npz')
high_null04_1 = high_null04['new_high_null_04_1']
high_null04_2 = high_null04['new_high_null_04_2']
high_null04_3 = high_null04['new_high_null_04_3']
high_null04_4 = high_null04['new_high_null_04_4']
high_null04_5 = high_null04['new_high_null_04_5']
high_null04_6 = high_null04['new_high_null_04_6']
high_null04_7 = high_null04['new_high_null_04_7']
high_null04_8 = high_null04['new_high_null_04_8']


high_null45 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_high_45.npz')
high_null45_1 = high_null45['new_high_null_45_1']
high_null45_2 = high_null45['new_high_null_45_2']
high_null45_3 = high_null45['new_high_null_45_3']
high_null45_4 = high_null45['new_high_null_45_4']
high_null45_5 = high_null45['new_high_null_45_5']
high_null45_6 = high_null45['new_high_null_45_6']
high_null45_7 = high_null45['new_high_null_45_7']
high_null45_8 = high_null45['new_high_null_45_8']


high_null05 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_high_05.npz')
high_null05_1 = high_null05['new_high_null_05_1']
high_null05_2 = high_null05['new_high_null_05_2']
high_null05_3 = high_null05['new_high_null_05_3']
high_null05_4 = high_null05['new_high_null_05_4']
high_null05_5 = high_null05['new_high_null_05_5']
high_null05_6 = high_null05['new_high_null_05_6']
high_null05_7 = high_null05['new_high_null_05_7']
high_null05_8 = high_null05['new_high_null_05_8']


high_null55 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_high_55.npz')
high_null55_1 = high_null55['new_high_null_55_1']
high_null55_2 = high_null55['new_high_null_55_2']
high_null55_3 = high_null55['new_high_null_55_3']
high_null55_4 = high_null55['new_high_null_55_4']
high_null55_5 = high_null55['new_high_null_55_5']
high_null55_6 = high_null55['new_high_null_55_6']
high_null55_7 = high_null55['new_high_null_55_7']
high_null55_8 = high_null55['new_high_null_55_8']


high_null06 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_high_06.npz')
high_null06_1 = high_null06['new_high_null_06_1']
high_null06_2 = high_null06['new_high_null_06_2']
high_null06_3 = high_null06['new_high_null_06_3']
high_null06_4 = high_null06['new_high_null_06_4']
high_null06_5 = high_null06['new_high_null_06_5']
high_null06_6 = high_null06['new_high_null_06_6']
high_null06_7 = high_null06['new_high_null_06_7']
high_null06_8 = high_null06['new_high_null_06_8']


high_null65 = np.load('/Users/mtownsend/Documents/LRG_Data/new_null_high_65.npz')
high_null65_1 = high_null65['new_high_null_65_1']
high_null65_2 = high_null65['new_high_null_65_2']
high_null65_3 = high_null65['new_high_null_65_3']
high_null65_4 = high_null65['new_high_null_65_4']
high_null65_5 = high_null65['new_high_null_65_5']
high_null65_6 = high_null65['new_high_null_65_6']
high_null65_7 = high_null65['new_high_null_65_7']
high_null65_8 = high_null65['new_high_null_65_8']

# %%
# read in unmasked data results

data_Nsat25 = np.load('/Users/mtownsend/Documents/LRG_Data/data_Nsat25_unmasked.npz')
Nsat_data25 = data_Nsat25['Nsat25']
print(Nsat_data25.shape)

data_Nsat03 = np.load('/Users/mtownsend/Documents/LRG_Data/data_Nsat03_unmasked.npz')
Nsat_data03 = data_Nsat03['Nsat03']
print(Nsat_data03.shape)

data_Nsat35 = np.load('/Users/mtownsend/Documents/LRG_Data/data_Nsat35_unmasked.npz')
Nsat_data35 = data_Nsat35['Nsat35']
print(Nsat_data35.shape)

data_Nsat04 = np.load('/Users/mtownsend/Documents/LRG_Data/data_Nsat04_unmasked.npz')
Nsat_data04 = data_Nsat04['Nsat04']
print(Nsat_data04.shape)

data_Nsat45 = np.load('/Users/mtownsend/Documents/LRG_Data/data_Nsat45_unmasked.npz')
Nsat_data45 = data_Nsat45['Nsat45']
print(Nsat_data45.shape)

data_Nsat05 = np.load('/Users/mtownsend/Documents/LRG_Data/data_Nsat05_unmasked.npz')
Nsat_data05 = data_Nsat05['Nsat05']
print(Nsat_data05.shape)

data_Nsat55 = np.load('/Users/mtownsend/Documents/LRG_Data/data_Nsat55_unmasked.npz')
Nsat_data55 = data_Nsat55['Nsat55']
print(Nsat_data55.shape)

data_Nsat06 = np.load('/Users/mtownsend/Documents/LRG_Data/data_Nsat06_unmasked.npz')
Nsat_data06 = data_Nsat06['Nsat06']
print(Nsat_data06.shape)

data_Nsat65 = np.load('/Users/mtownsend/Documents/LRG_Data/data_Nsat65_unmasked.npz')
Nsat_data65 = data_Nsat65['Nsat65']
print(Nsat_data65.shape)
# Out:
# (90, 49, 49, 49)
# (83, 49, 49, 49)
# (136, 49, 49, 49)
# (128, 49, 49, 49)
# (180, 49, 49, 49)
# (309, 49, 49, 49)
# (386, 49, 49, 49)
# (325, 49, 49, 49)
# (186, 49, 49, 49)

# %%
# read in selection matrices for each luminosity selected sample 

data_smatrix03 = np.load('/Users/mtownsend/Desktop/lowz_smatrix-2matrices.npz')
smatrix03 = data_smatrix03['smatrix_low']
print(smatrix03.shape)

data_smatrix04 = np.load('/Users/mtownsend/Desktop/midz1_smatrix-4matrices.npz')
smatrix04 = data_smatrix04['smatrix_low']
print(smatrix04.shape)

data_smatrix05 = np.load('/Users/mtownsend/Desktop/midz2_smatrix-6matrices.npz')
smatrix05 = data_smatrix05['smatrix_low']
print(smatrix05.shape)

data_smatrix06 = np.load('/Users/mtownsend/Desktop/midz3_smatrix-8matrices.npz')
smatrix06 = data_smatrix06['smatrix_low']
print(smatrix06.shape)

data_smatrix65 = np.load('/Users/mtownsend/Desktop/highz_smatrix-9matrices.npz')
smatrix65 = data_smatrix65['smatrix_low']
print(smatrix65.shape)
# Out:
# (2, 49, 49, 49)
# (4, 49, 49, 49)
# (6, 49, 49, 49)
# (8, 49, 49, 49)
# (9, 49, 49, 49)

# %%
# make masked Nsat for log(lum)=9.55; 0.2 < z < 0.3

# 0.2 < z < 0.25
lowz_maskedNsat25 = []
for i in range(len(Nsat_data25)):
    lowz_maskedNsat25.append(Nsat_data25[i] * smatrix03[0])
    
# 0.25 < z < 0.3
lowz_maskedNsat03 = []
for i in range(len(Nsat_data03)):
    lowz_maskedNsat03.append(Nsat_data03[i] * smatrix03[1])

print(np.asarray(lowz_maskedNsat25).shape)
print(np.asarray(lowz_maskedNsat03).shape)
# Out:
# (90, 49, 49, 49)
# (83, 49, 49, 49)

# %%
# make masked Nsat for log(lum)=9.84; 0.2 < z < 0.4

# 0.2 < z < 0.25
mid1_maskedNsat25 = []
for i in range(len(Nsat_data25)):
    mid1_maskedNsat25.append(Nsat_data25[i] * smatrix04[0])
    
# 0.25 < z < 0.3
mid1_maskedNsat03 = []
for i in range(len(Nsat_data03)):
    mid1_maskedNsat03.append(Nsat_data03[i] * smatrix04[1])
    
# 0.3 < z < 0.35
mid1_maskedNsat35 = []
for i in range(len(Nsat_data35)):
    mid1_maskedNsat35.append(Nsat_data35[i] * smatrix04[2])
    
# 0.35 < z < 0.4
mid1_maskedNsat04 = []
for i in range(len(Nsat_data04)):
    mid1_maskedNsat04.append(Nsat_data04[i] * smatrix04[3])


print(np.asarray(mid1_maskedNsat25).shape)
print(np.asarray(mid1_maskedNsat03).shape)
print(np.asarray(mid1_maskedNsat35).shape)
print(np.asarray(mid1_maskedNsat04).shape)
# Out:
# (90, 49, 49, 49)
# (83, 49, 49, 49)
# (136, 49, 49, 49)
# (128, 49, 49, 49)

# %%
# make masked Nsat for log(lum)=10.13; 0.2 < z < 0.5

# 0.2 < z < 0.25
mid2_maskedNsat25 = []
for i in range(len(Nsat_data25)):
    mid2_maskedNsat25.append(Nsat_data25[i] * smatrix05[0])
    
# 0.25 < z < 0.3
mid2_maskedNsat03 = []
for i in range(len(Nsat_data03)):
    mid2_maskedNsat03.append(Nsat_data03[i] * smatrix05[1])
    
# 0.3 < z < 0.35
mid2_maskedNsat35 = []
for i in range(len(Nsat_data35)):
    mid2_maskedNsat35.append(Nsat_data35[i] * smatrix05[2])
    
# 0.35 < z < 0.4
mid2_maskedNsat04 = []
for i in range(len(Nsat_data04)):
    mid2_maskedNsat04.append(Nsat_data04[i] * smatrix05[3])
    
# 0.4 < z < 0.45
mid2_maskedNsat45 = []
for i in range(len(Nsat_data45)):
    mid2_maskedNsat45.append(Nsat_data45[i] * smatrix05[4])
    
# 0.45 < z < 0.5
mid2_maskedNsat05 = []
for i in range(len(Nsat_data05)):
    mid2_maskedNsat05.append(Nsat_data05[i] * smatrix05[5])


print(np.asarray(mid2_maskedNsat25).shape)
print(np.asarray(mid2_maskedNsat03).shape)
print(np.asarray(mid2_maskedNsat35).shape)
print(np.asarray(mid2_maskedNsat04).shape)
print(np.asarray(mid2_maskedNsat45).shape)
print(np.asarray(mid2_maskedNsat05).shape)
# Out:
# (90, 49, 49, 49)
# (83, 49, 49, 49)
# (136, 49, 49, 49)
# (128, 49, 49, 49)
# (180, 49, 49, 49)
# (309, 49, 49, 49)

# %%
# make masked Nsat for log(lum)=10.36; 0.2 < z < 0.6

# 0.2 < z < 0.25
mid3_maskedNsat25 = []
for i in range(len(Nsat_data25)):
    mid3_maskedNsat25.append(Nsat_data25[i] * smatrix06[0])
    
# 0.25 < z < 0.3
mid3_maskedNsat03 = []
for i in range(len(Nsat_data03)):
    mid3_maskedNsat03.append(Nsat_data03[i] * smatrix06[1])
    
# 0.3 < z < 0.35
mid3_maskedNsat35 = []
for i in range(len(Nsat_data35)):
    mid3_maskedNsat35.append(Nsat_data35[i] * smatrix06[2])
    
# 0.35 < z < 0.4
mid3_maskedNsat04 = []
for i in range(len(Nsat_data04)):
    mid3_maskedNsat04.append(Nsat_data04[i] * smatrix06[3])
    
# 0.4 < z < 0.45
mid3_maskedNsat45 = []
for i in range(len(Nsat_data45)):
    mid3_maskedNsat45.append(Nsat_data45[i] * smatrix06[4])
    
# 0.45 < z < 0.5
mid3_maskedNsat05 = []
for i in range(len(Nsat_data05)):
    mid3_maskedNsat05.append(Nsat_data05[i] * smatrix06[5])
    
# 0.5 < z < 0.55
mid3_maskedNsat55 = []
for i in range(len(Nsat_data55)):
    mid3_maskedNsat55.append(Nsat_data55[i] * smatrix06[6])
    
# 0.55 < z < 0.6
mid3_maskedNsat06 = []
for i in range(len(Nsat_data06)):
    mid3_maskedNsat06.append(Nsat_data06[i] * smatrix06[7])


print(np.asarray(mid3_maskedNsat25).shape)
print(np.asarray(mid3_maskedNsat03).shape)
print(np.asarray(mid3_maskedNsat35).shape)
print(np.asarray(mid3_maskedNsat04).shape)
print(np.asarray(mid3_maskedNsat45).shape)
print(np.asarray(mid3_maskedNsat05).shape)
print(np.asarray(mid3_maskedNsat55).shape)
print(np.asarray(mid3_maskedNsat06).shape)
# Out:
# (90, 49, 49, 49)
# (83, 49, 49, 49)
# (136, 49, 49, 49)
# (128, 49, 49, 49)
# (180, 49, 49, 49)
# (309, 49, 49, 49)
# (386, 49, 49, 49)
# (325, 49, 49, 49)

# %%
# make masked Nsat for log(lum)=10.47; 0.2 < z < 0.65

# 0.2 < z < 0.25
high_maskedNsat25 = []
for i in range(len(Nsat_data25)):
    high_maskedNsat25.append(Nsat_data25[i] * smatrix65[0])
    
# 0.25 < z < 0.3
high_maskedNsat03 = []
for i in range(len(Nsat_data03)):
    high_maskedNsat03.append(Nsat_data03[i] * smatrix65[1])
    
# 0.3 < z < 0.35
high_maskedNsat35 = []
for i in range(len(Nsat_data35)):
    high_maskedNsat35.append(Nsat_data35[i] * smatrix65[2])
    
# 0.35 < z < 0.4
high_maskedNsat04 = []
for i in range(len(Nsat_data04)):
    high_maskedNsat04.append(Nsat_data04[i] * smatrix65[3])
    
# 0.4 < z < 0.45
high_maskedNsat45 = []
for i in range(len(Nsat_data45)):
    high_maskedNsat45.append(Nsat_data45[i] * smatrix65[4])
    
# 0.45 < z < 0.5
high_maskedNsat05 = []
for i in range(len(Nsat_data05)):
    high_maskedNsat05.append(Nsat_data05[i] * smatrix65[5])
    
# 0.5 < z < 0.55
high_maskedNsat55 = []
for i in range(len(Nsat_data55)):
    high_maskedNsat55.append(Nsat_data55[i] * smatrix65[6])
    
# 0.55 < z < 0.6
high_maskedNsat06 = []
for i in range(len(Nsat_data06)):
    high_maskedNsat06.append(Nsat_data06[i] * smatrix65[7])

# 0.6 < z < 0.65
high_maskedNsat65 = []
for i in range(len(Nsat_data65)):
    high_maskedNsat65.append(Nsat_data65[i] * smatrix65[8])


print(np.asarray(high_maskedNsat25).shape)
print(np.asarray(high_maskedNsat03).shape)
print(np.asarray(high_maskedNsat35).shape)
print(np.asarray(high_maskedNsat04).shape)
print(np.asarray(high_maskedNsat45).shape)
print(np.asarray(high_maskedNsat05).shape)
print(np.asarray(high_maskedNsat55).shape)
print(np.asarray(high_maskedNsat06).shape)
print(np.asarray(high_maskedNsat65).shape)
# Out:
# (90, 49, 49, 49)
# (83, 49, 49, 49)
# (136, 49, 49, 49)
# (128, 49, 49, 49)
# (180, 49, 49, 49)
# (309, 49, 49, 49)
# (386, 49, 49, 49)
# (325, 49, 49, 49)
# (186, 49, 49, 49)

# %%
def totalNsat(Nsat, lum, z1, z2, string):

    import matplotlib.pylab as plt 
    import numpy as np
    from scipy import stats
    
    left, width = .25, .5
    bottom, height = .25, .5
    right = left + width
    top = bottom + height


    sumsat = []

    # Sum up number of satellite galaxies for every LRG
    for i in range(len(Nsat)):
        sumsat.append(np.sum(Nsat[i]))

    meansat = np.mean(sumsat)
    print("mean number of satellites is", meansat)
    
    mediansat = np.median(sumsat)
#     print("median number of satellites is", mediansat)

    sdsat = np.std(sumsat)
#     print("standard deviation of satellites is", sdsat)

    sterr = stats.sem(sumsat)
#     print("standard error is", sterr)
    
    eighty = np.percentile(sumsat, 80.)
#     print("80th percentile = ", eighty)
    ninety = np.percentile(sumsat, 90.)
#     print("90th percentile = ", ninety)
    ninetynine = np.percentile(sumsat, 99.)
#     print("99th percentile = ", ninetynine)

    plt.rcParams["figure.figsize"] = [15, 8]
    fig = plt.figure()
    ax = fig.add_subplot(111)
#     plt.title("Histogram of the Number of Satellite Galaxies; log(lum)=10.36; 0.55 < z < 0.6", fontsize=25)
    plt.title("Histogram of the Number of Satellite Galaxies; log(lum)={}; {} < z < {}; ({})".format(lum, z1, z2, string), fontsize=18)
    plt.hist(sumsat, bins=50)
    plt.xlabel(r'$Number$ $of$ $Satellite$ $Galaxies$', fontsize=20)
    plt.ylabel(r'$counts$', fontsize=20)
#     plt.axvline(x=eighty, linewidth=1, ls='-', color='r')
#     plt.axvline(x=ninety, linewidth=1, ls='--', color='g')
#     plt.axvline(x=ninetynine, linewidth=1, ls=':', color='b')
    plt.text(top, right,'mean = {}'.format(meansat), fontsize=14, ha='center', va='center', transform=ax.transAxes)
    plt.text(top, right-0.05,'median = {}'.format(mediansat), fontsize=14, ha='center', va='center', transform=ax.transAxes)
#     plt.text(top, right-0.1,'99th = {}'.format(ninetynine), fontsize=14, ha='center', va='center', transform=ax.transAxes)
    # plt.show()
    return(sumsat)

# %%
# misc data for use in A-D function

rz = np.load('/Users/mtownsend/Documents/LRG_Data/random_rzcolor.npz')

rz_rand1 = rz['rz_rand1']
print(len(rz_rand1))
rz_rand2 = rz['rz_rand2']
print(len(rz_rand2))
rz_rand3 = rz['rz_rand3']
print(len(rz_rand3))
rz_rand4 = rz['rz_rand4']
print(len(rz_rand4))
rz_rand5 = rz['rz_rand5']
print(len(rz_rand5))
rz_rand6 = rz['rz_rand6']
print(len(rz_rand6))
rz_rand7 = rz['rz_rand7']
print(len(rz_rand7))
rz_rand8 = rz['rz_rand8']
print(len(rz_rand8))

# create redshift bins

zinit = 0.2
zfin = 0.65
interval = 0.05
# num = (zfin-zinit)/interval
num = 10. 
zrange, step = np.linspace(zinit, zfin, num=int(num), retstep=True)
# Out:
# 3
# 1
# 4
# 4
# 5
# 5
# 7
# 7

# %%
# model comparision for lowz 

# models for 0.2 < 0.25

# sumsat25_model1 = totalNsat(low_null25_1, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'model 1')
# sumsat25_model2 = totalNsat(low_null25_2, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'model 2')
# sumsat25_model3 = totalNsat(low_null25_3, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'model 3')
# sumsat25_model4 = totalNsat(low_null25_4, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'model 4')
# sumsat25_model5 = totalNsat(low_null25_5, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'model 5')
# sumsat25_model6 = totalNsat(low_null25_6, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'model 6')
# sumsat25_model7 = totalNsat(low_null25_7, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'model 7')
sumsat25_model8 = totalNsat(low_null25_8, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'model 8')


# models for 0.25 < 0.3

# sumsat03_model1 = totalNsat(low_null03_1, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'model 1')
# sumsat03_model2 = totalNsat(low_null03_2, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'model 2')
# sumsat03_model3 = totalNsat(low_null03_3, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'model 3')
# sumsat03_model4 = totalNsat(low_null03_4, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'model 4')
# sumsat03_model5 = totalNsat(low_null03_5, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'model 5')
# sumsat03_model6 = totalNsat(low_null03_6, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'model 6')
# sumsat03_model7 = totalNsat(low_null03_7, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'model 7')
# sumsat03_model8 = totalNsat(low_null03_8, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'model 8')


# data

sumsat25_data = totalNsat(lowz_maskedNsat25, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'data')
# sumsat03_data = totalNsat(lowz_maskedNsat03, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'data')


# perform k-sample Anderson-Darling test on null+gauss distributions and data

from scipy import stats

stat25, crit_vals25, sig_level25 = stats.anderson_ksamp([sumsat25_model8, sumsat25_data])
# stat03, crit_vals03, sig_level03 = stats.anderson_ksamp([sumsat03_model1, sumsat03_data])

print(stat25)
print(crit_vals25)
print(sig_level25)

print('----')

# print(stat03)
# print(crit_vals03)
# print(sig_level03)


stat, pval = stats.ks_2samp(sumsat25_model8, sumsat25_data)

print(stat)
print(pval)
# Out:
# mean number of satellites is 1.7910799654982048
# mean number of satellites is 0.732166005879621
# 7.836024151123989
# [0.325 1.226 1.961 2.718 3.752]
# 0.00047446508695291615
# ----
# 0.18472993215261257
# 0.004486755798042313

# %%
from scipy import stats

np.random.seed(314159)

stats.anderson_ksamp([np.random.normal(size=50), np.random.normal(loc=0.5, size=30)])

print('----')

stats.anderson_ksamp([np.random.normal(size=50), np.random.normal(size=30), np.random.normal(size=20)])
# Out:
# ----
# Anderson_ksampResult(statistic=-0.7309172266524393, critical_values=array([0.44925884, 1.3052767 , 1.9434184 , 2.57696569, 3.41634856]), significance_level=0.8789283903979626)
