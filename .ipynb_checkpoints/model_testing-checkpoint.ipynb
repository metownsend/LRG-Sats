# %%
from astropy.io import fits
from astropy.table import Table
import numpy as np
import matplotlib.pylab as plt 
import matplotlib.lines as mlines
from matplotlib.legend import Legend
from pythonds.basic.stack import Stack
from math import *
from sklearn.neighbors import KDTree
# from lrg_plot_functions import *
from lrg_sum_functions import *
from cosmo_Calc import *
from divideByTwo import *
from read_data import *
from nearNeighbors import *
from scipy import stats
from astropy import stats
import healpy as hp
from localBKG_and_interlopersHEALPix import *
# import healpy as hpy
from makeCutoutTableFunc import *
from plotHistogramProjections3D import *
from read_bricks import *
from mpl_toolkits.axes_grid1 import make_axes_locatable
import random

# %%
def totalNsat(Nsat, lum, z1, z2, string):

    import matplotlib.pylab as plt 
    import numpy as np
    from scipy import stats
    
    left, width = .25, .5
    bottom, height = .25, .5
    right = left + width
    top = bottom + height


    sumsat = []

    # Sum up number of satellite galaxies for every LRG
    for i in range(len(Nsat)):
        sumsat.append(np.sum(Nsat[i]))

    meansat = np.mean(sumsat)
#     print("mean number of satellites is", meansat)
    
    mediansat = np.median(sumsat)
#     print("median number of satellites is", mediansat)

    sdsat = np.std(sumsat)
#     print("standard deviation of satellites is", sdsat)

    sterr = stats.sem(sumsat)
#     print("standard error is", sterr)
    
    eighty = np.percentile(sumsat, 80.)
#     print("80th percentile = ", eighty)
    ninety = np.percentile(sumsat, 90.)
#     print("90th percentile = ", ninety)
    ninetynine = np.percentile(sumsat, 99.)
#     print("99th percentile = ", ninetynine)

    plt.rcParams["figure.figsize"] = [15, 8]
    fig = plt.figure()
    ax = fig.add_subplot(111)
#     plt.title("Histogram of the Number of Satellite Galaxies; log(lum)=10.36; 0.55 < z < 0.6", fontsize=25)
    plt.title("Histogram of the Number of Satellite Galaxies; log(lum)={}; {} < z < {}; ({})".format(lum, z1, z2, string), fontsize=18)
    plt.hist(sumsat, bins=50)
    plt.xlabel(r'$Number$ $of$ $Satellite$ $Galaxies$', fontsize=20)
    plt.ylabel(r'$counts$', fontsize=20)
#     plt.axvline(x=eighty, linewidth=1, ls='-', color='r')
#     plt.axvline(x=ninety, linewidth=1, ls='--', color='g')
#     plt.axvline(x=ninetynine, linewidth=1, ls=':', color='b')
    plt.text(top, right,'mean = {}'.format(meansat), fontsize=14, ha='center', va='center', transform=ax.transAxes)
    plt.text(top, right-0.05,'median = {}'.format(mediansat), fontsize=14, ha='center', va='center', transform=ax.transAxes)
#     plt.text(top, right-0.1,'99th = {}'.format(ninetynine), fontsize=14, ha='center', va='center', transform=ax.transAxes)
    # plt.show()
    return(sumsat)

# %%
# read in null results before selection matrices are applied

data_Nsat25 = np.load('/Users/mtownsend/Documents/LRG_Data/null_Nsat25_low.npz')
Nsat_new25 = data_Nsat25['Nsat25']
print(Nsat_new25.shape)

print('----')

data_Nsat03 = np.load('/Users/mtownsend/Documents/LRG_Data/null_Nsat03_low.npz')
Nsat_new03 = data_Nsat03['Nsat03']
print(Nsat_new03.shape)

# print('----')

# data_Nsat35 = np.load('/Users/mtownsend/Documents/LRG_Data/null_Nsat35_high.npz')
# null_Nsat_new35 = data_Nsat35['Nsat35']
# print(null_Nsat_new35.shape)

# print('----')

# data_Nsat04 = np.load('/Users/mtownsend/Documents/LRG_Data/null_Nsat04_high.npz')
# null_Nsat_new04 = data_Nsat04['Nsat04']
# print(null_Nsat_new04.shape)

# print('----')

# data_Nsat45 = np.load('/Users/mtownsend/Documents/LRG_Data/null_Nsat45_high.npz')
# null_Nsat_new45 = data_Nsat45['Nsat45']
# print(null_Nsat_new45.shape)

# print('----')

# data_Nsat05 = np.load('/Users/mtownsend/Documents/LRG_Data/null_Nsat05_high.npz')
# null_Nsat_new05 = data_Nsat05['Nsat05']
# print(null_Nsat_new05.shape)

# print('----')

# data_Nsat55 = np.load('/Users/mtownsend/Documents/LRG_Data/null_Nsat55_high.npz')
# null_Nsat_new55 = data_Nsat55['Nsat55']
# print(null_Nsat_new55.shape)

# print('----')

# data_Nsat06 = np.load('/Users/mtownsend/Documents/LRG_Data/null_Nsat06_high.npz')
# null_Nsat_new06 = data_Nsat06['Nsat06']
# print(null_Nsat_new06.shape)

# print('----')

# data_Nsat65 = np.load('/Users/mtownsend/Documents/LRG_Data/null_Nsat65_high.npz')
# null_Nsat_new65 = data_Nsat65['Nsat65']
# print(null_Nsat_new65.shape)
# Out:
# (2522, 49, 49, 49)
# ----
# (2478, 49, 49, 49)

# %%
# read in selection matrices for each luminosity selected sample 

data_smatrix03 = np.load('/Users/mtownsend/Desktop/lowz_smatrix-2matrices.npz')
smatrix03 = data_smatrix03['smatrix_low']
print(smatrix03.shape)

data_smatrix04 = np.load('/Users/mtownsend/Desktop/midz1_smatrix-4matrices.npz')
smatrix04 = data_smatrix04['smatrix_low']
print(smatrix04.shape)

data_smatrix05 = np.load('/Users/mtownsend/Desktop/midz2_smatrix-6matrices.npz')
smatrix05 = data_smatrix05['smatrix_low']
print(smatrix05.shape)

data_smatrix06 = np.load('/Users/mtownsend/Desktop/midz3_smatrix-8matrices.npz')
smatrix06 = data_smatrix06['smatrix_low']
print(smatrix06.shape)

data_smatrix65 = np.load('/Users/mtownsend/Desktop/highz_smatrix-9matrices.npz')
smatrix65 = data_smatrix65['smatrix_low']
print(smatrix65.shape)
# Out:
# (2, 49, 49, 49)
# (4, 49, 49, 49)
# (6, 49, 49, 49)
# (8, 49, 49, 49)
# (9, 49, 49, 49)

# %%
zinit = 0.2
zfin = 0.65
interval = 0.05
# num = (zfin-zinit)/interval
num = 10. 
zrange, step = np.linspace(zinit, zfin, num=int(num), retstep=True)

# %%
# models to test

gauss2 = np.random.normal(loc=2., scale=1., size=1)
print(int(gauss2))

gauss3 = np.random.normal(loc=3., scale=1., size=1)
print(int(gauss3))

gauss4 = np.random.normal(loc=4., scale=1., size=1)
print(int(gauss4))

gauss5 = np.random.normal(loc=5., scale=1., size=1)
print(int(gauss5))
# Out:
# 2
# 1
# 3
# 4

# %%
# find cells of selectrion matrices that are equal to 1

# smatrix0 = smatrix03[0]
# print(smatrix0.shape)
# smatrix1 = smatrix03[1]
# print(smatrix1.shape)

low_result0 = np.argwhere(smatrix03[0] == 1)
low_result1 = np.argwhere(smatrix03[1] == 1)
# print(len(low_result0))
# print(len(low_result1))

# print('----')

mid1_result0 = np.argwhere(smatrix04[0] == 1)
mid1_result1 = np.argwhere(smatrix04[1] == 1)
mid1_result2 = np.argwhere(smatrix04[2] == 1)
mid1_result3 = np.argwhere(smatrix04[3] == 1)
# print(len(mid1_result0))
# print(len(mid1_result1))
# print(len(mid1_result2))
# print(len(mid1_result3))

# print('----')

mid2_result0 = np.argwhere(smatrix05[0] == 1)
mid2_result1 = np.argwhere(smatrix05[1] == 1)
mid2_result2 = np.argwhere(smatrix05[2] == 1)
mid2_result3 = np.argwhere(smatrix05[3] == 1)
mid2_result4 = np.argwhere(smatrix05[4] == 1)
mid2_result5 = np.argwhere(smatrix05[5] == 1)
# print(len(mid2_result0))
# print(len(mid2_result1))
# print(len(mid2_result2))
# print(len(mid2_result3))
# print(len(mid2_result4))
# print(len(mid2_result5))

# print('----')

mid3_result0 = np.argwhere(smatrix06[0] == 1)
mid3_result1 = np.argwhere(smatrix06[1] == 1)
mid3_result2 = np.argwhere(smatrix06[2] == 1)
mid3_result3 = np.argwhere(smatrix06[3] == 1)
mid3_result4 = np.argwhere(smatrix06[4] == 1)
mid3_result5 = np.argwhere(smatrix06[5] == 1)
mid3_result6 = np.argwhere(smatrix06[6] == 1)
mid3_result7 = np.argwhere(smatrix06[7] == 1)
# print(len(mid3_result0))
# print(len(mid3_result1))
# print(len(mid3_result2))
# print(len(mid3_result3))
# print(len(mid3_result4))
# print(len(mid3_result5))
# print(len(mid3_result6))
# print(len(mid3_result7))

# print('----')

high_result0 = np.argwhere(smatrix65[0] == 1)
high_result1 = np.argwhere(smatrix65[1] == 1)
high_result2 = np.argwhere(smatrix65[2] == 1)
high_result3 = np.argwhere(smatrix65[3] == 1)
high_result4 = np.argwhere(smatrix65[4] == 1)
high_result5 = np.argwhere(smatrix65[5] == 1)
high_result6 = np.argwhere(smatrix65[6] == 1)
high_result7 = np.argwhere(smatrix65[7] == 1)
high_result8 = np.argwhere(smatrix65[8] == 1)
# print(len(high_result0))
# print(len(high_result1))
# print(len(high_result2))
# print(len(high_result3))
# print(len(high_result4))
# print(len(high_result5))
# print(len(high_result6))
# print(len(high_result7))
# print(len(high_result8))

# %%
#determine indices at which to place additional sources

low_index0 = np.random.randint(0,len(low_result0),size=int(gauss5))
print(low_index0)
print(low_result0[low_index0])

print('----')

low_index1 = np.random.randint(0,len(low_result1),size=int(gauss5))
print(low_index1)
print(low_result1[low_index1])
# Out:
# [154  76 138  45]
# [[ 9 22  1]
#  [ 9 19  1]
#  [ 9 21 11]
#  [ 8 21 20]]
# ----
# [436 263  36 440]
# [[10 25 10]
#  [ 9 21 26]
#  [ 7 20  7]
#  [10 25 14]]

# %%
# add one at index location

# print(Nsat25[0,9,23,18])
# Nsat25[0,9,23,18] = Nsat25[0,9,23,28] + 1.
# print(Nsat25[0,9,23,18])

Nsat25 = Nsat_new25
Nsat03 = Nsat_new03

for i in range(len(Nsat_new25)):
    Nsat25[i,9,22,1] = Nsat_new25[i,9,22,1] + 1
    Nsat25[i,9,19,1] = Nsat_new25[i,9,19,1] + 1
    Nsat25[i,9,21,11] = Nsat_new25[i,9,21,11] + 1
    Nsat25[i,8,21,20] = Nsat_new25[i,8,21,20] + 1
    
np.savez('/Users/mtownsend/Documents/LRG_Data/null_Nsat25_gauss5_low.npz', Nsat25=Nsat25)

for i in range(len(Nsat_new03)):
    Nsat03[i,10,25,10] = Nsat_new03[i,10,25,10] + 1
    Nsat03[i,9,21,26] = Nsat_new03[i,9,21,26] + 1
    Nsat03[i,7,20,7] = Nsat_new03[i,7,20,7] + 1
    Nsat03[i,10,25,14] = Nsat_new03[i,10,25,14] + 1

np.savez('/Users/mtownsend/Documents/LRG_Data/null_Nsat03_gauss5_low.npz', Nsat03=Nsat03)

# %%
# make new Nsat for log(lum)=9.55; 0.2 < z < 0.3

# 0.2 < z < 0.25
lowz_newNsat25 = []
for i in range(len(Nsat25)):
    lowz_newNsat25.append(Nsat25[i] * smatrix03[0])
    
# 0.25 < z < 0.3
lowz_newNsat03 = []
for i in range(len(Nsat03)):
    lowz_newNsat03.append(Nsat03[i] * smatrix03[1])

print(np.asarray(lowz_newNsat25).shape)
print(np.asarray(lowz_newNsat03).shape)


# # 0.2 < z < 0.25
# lowz_newNsat25_OG = []
# for i in range(len(Nsat_new25)):
#     lowz_newNsat25_OG.append(Nsat_new25[i] * smatrix03[0])
    
# # 0.25 < z < 0.3
# lowz_newNsat03_OG = []
# for i in range(len(Nsat_new03)):
#     lowz_newNsat03_OG.append(Nsat_new03[i] * smatrix03[1])
# Out:
# (2522, 49, 49, 49)
# (2478, 49, 49, 49)

# %%
totalNsat(lowz_newNsat25, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'gauss 5')

plt.savefig('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/lowz_null_maskedNsat25_gauss5.pdf')
plt.show()

totalNsat(lowz_newNsat03, 9.55, round(zrange[1], 2), round(zrange[2], 2), 'gauss 5')

plt.savefig('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/lowz_null_maskedNsat03_gauss5.pdf')
plt.show()

# totalNsat(lowz_newNsat25_OG, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'original')

# plt.savefig('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/lowz_null_maskedNsat25_OG.pdf')
# plt.show()

# totalNsat(lowz_newNsat03_OG, 9.55, round(zrange[1], 2), round(zrange[2], 2), 'original')

# plt.savefig('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/lowz_null_maskedNsat03_OG.pdf')
# plt.show()

# %%
# read in data results

data_Nsat25 = np.load('/Users/mtownsend/Documents/LRG_Data/data_Nsat25_unmasked.npz')
Nsat_data25 = data_Nsat25['Nsat25']
print(Nsat_data25.shape)

data_Nsat03 = np.load('/Users/mtownsend/Documents/LRG_Data/data_Nsat03_unmasked.npz')
Nsat_data03 = data_Nsat03['Nsat03']
print(Nsat_data03.shape)

# apply masks to data

# 0.2 < z < 0.25
lowz_dataNsat25 = []
for i in range(len(Nsat_data25)):
    lowz_dataNsat25.append(Nsat_data25[i] * smatrix03[0])
    
# 0.25 < z < 0.3
lowz_dataNsat03 = []
for i in range(len(Nsat_data03)):
    lowz_dataNsat03.append(Nsat_data03[i] * smatrix03[1])

print(np.asarray(lowz_dataNsat25).shape)
print(np.asarray(lowz_dataNsat03).shape)


# read in null+gauss2 results

# gauss2_Nsat25 = np.load('/Users/mtownsend/Documents/LRG_Data/null_Nsat25_gauss2_low.npz')
# Nsat25_gauss2 = gauss2_Nsat25['Nsat25']
# print(Nsat25_gauss2.shape)

# gauss2_Nsat03 = np.load('/Users/mtownsend/Documents/LRG_Data/null_Nsat03_gauss2_low.npz')
# Nsat03_gauss2 = gauss2_Nsat03['Nsat03']
# print(Nsat03_gauss2.shape)

gauss3_Nsat25 = np.load('/Users/mtownsend/Documents/LRG_Data/null_Nsat25_gauss3_low.npz')
Nsat25_gauss3 = gauss3_Nsat25['Nsat25']
print(Nsat25_gauss3.shape)

gauss3_Nsat03 = np.load('/Users/mtownsend/Documents/LRG_Data/null_Nsat03_gauss3_low.npz')
# gauss3_Nsat03.keys()
Nsat03_gauss3 = gauss3_Nsat03['Nsat03']
print(Nsat03_gauss2.shape)

# apply masks to data

# 0.2 < z < 0.25
lowz_gaussNsat25 = []
for i in range(len(Nsat25_gauss3)):
    lowz_gaussNsat25.append(Nsat25_gauss3[i] * smatrix03[0])
    
# 0.25 < z < 0.3
lowz_gaussNsat03 = []
for i in range(len(Nsat03_gauss3)):
    lowz_gaussNsat03.append(Nsat03_gauss3[i] * smatrix03[1])

print(np.asarray(lowz_gaussNsat25).shape)
print(np.asarray(lowz_gaussNsat03).shape)
# Out:
# (90, 49, 49, 49)
# (83, 49, 49, 49)
# (90, 49, 49, 49)
# (83, 49, 49, 49)
# (2522, 49, 49, 49)
# (2478, 49, 49, 49)
# (2522, 49, 49, 49)
# (2478, 49, 49, 49)

# %%
sumsat25_gauss3 = totalNsat(lowz_gaussNsat25, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'gauss 3')
sumsat03_gauss3 = totalNsat(lowz_gaussNsat03, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'gauss 3')

sumsat25_data = totalNsat(lowz_dataNsat25, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'data')
sumsat03_data = totalNsat(lowz_dataNsat03, 9.55, round(zrange[0], 2), round(zrange[1], 2), 'data')

# %%
# perform k-sample Anderson-Darling test on null+gauss distributions and data

from scipy import stats

stat25, crit_vals25, sig_level25 = stats.anderson_ksamp([sumsat25_gauss3, sumsat25_data])
stat03, crit_vals03, sig_level03 = stats.anderson_ksamp([sumsat03_gauss3, sumsat03_data])

print(stat25)
print(crit_vals25)
print(sig_level25)

print('----')

print(stat03)
print(crit_vals03)
print(sig_level03)
# Out:
# 303.0951355179849
# [0.325 1.226 1.961 2.718 3.752]
# inf
# ----
# 283.43720558870825
# [0.325 1.226 1.961 2.718 3.752]
# inf
