# %%
from astropy.io import fits
from astropy.table import Table
import numpy as np
import matplotlib.pylab as plt 
import matplotlib.lines as mlines
from matplotlib.legend import Legend
from pythonds.basic.stack import Stack
from math import *
from sklearn.neighbors import KDTree
from lrg_plot_functions import *
from lrg_sum_functions import *
from cosmo_Calc import *
from divideByTwo import *
from read_data import *
from nearNeighbors import *
from scipy import stats
from astropy import stats
import healpy as hp
from localBKG_and_interlopersHEALPix import *
# import healpy as hpy
from makeCutoutTableFunc import *
from plotHistogramProjections3D import *
from read_bricks import *
from mpl_toolkits.axes_grid1 import make_axes_locatable
import random
from sigSats import *
from sigSats_usingSumsat import *
from confidence_interval import *

# %%
# read in MASKED Nsat data 


# lowz
data_Nsat_low = np.load('/Users/mtownsend/Documents/LRG_Data/masked_Nsat_low-EDR.npz')
Nsat35_low = data_Nsat_low['masked_Nsat_low35']

# midz
data_Nsat_mid = np.load('/Users/mtownsend/Documents/LRG_Data/masked_Nsat_mid-EDR.npz')
Nsat35_mid = data_Nsat_mid['masked_Nsat_mid35']
Nsat05_mid = data_Nsat_mid['masked_Nsat_mid05']

# highz
data_Nsat_high = np.load('/Users/mtownsend/Documents/LRG_Data/masked_Nsat_high-EDR.npz')
Nsat35_high = data_Nsat_high['masked_Nsat_high35']
Nsat05_high = data_Nsat_high['masked_Nsat_high05']
Nsat65_high = data_Nsat_high['masked_Nsat_high65']

print('----')


# zinit = 0.2
# zfin = 0.65
# # interval = 0.5
# # num = (zfin-zinit)/interval
# num = 3. 
# zrange, step = np.linspace(zinit, zfin, num=int(num), retstep=True)
zrange = [0.2, 0.35, 0.5, 0.65]
print(zrange)
# Out:
# ----
# [0.2, 0.35, 0.5, 0.65]

# %%
# # read in files with the number of satellites for 80, 90, and 99 percentiles for each LRG redshift/luminosity bin

# low
plow = np.load('/Users/mtownsend/Documents/LRG_Data/percentiles_low-EDR.npz')
plow35 = plow['low_p35']

# mid
pmid = np.load('/Users/mtownsend/Documents/LRG_Data/percentiles_mid-EDR.npz')
pmid35 = pmid['mid_p35']
pmid05 = pmid['mid_p05']

# high
phigh = np.load('/Users/mtownsend/Documents/LRG_Data/percentiles_high-EDR.npz')
phigh35 = phigh['high_p35']
phigh05 = phigh['high_p05']
phigh65 = phigh['high_p65']

# %%
# def totalNsat(Nsat, lum, z1, z2):
# def totalNsat(sumsat, lum, z1, z2):
def totalNsat(sumsat, lum, z1, z2, ci_l, ci_u):

    import matplotlib.pylab as plt 	
    import numpy as np
    from scipy import stats
    
    left, width = .25, .5
    bottom, height = .25, .5
    right = left + width
    top = bottom + height


#     sumsat = []

#     # Sum up number of satellite galaxies for every LRG
#     for i in range(len(Nsat)):
#         sumsat.append(np.sum(Nsat[i]))

    meansat = np.mean(sumsat)
#     print("mean number of satellites is", meansat)
    
    mediansat = np.median(sumsat)
#     print("median number of satellites is", mediansat)

    sdsat = np.std(sumsat)
#     print("standard deviation of satellites is", sdsat)

    sterr = stats.sem(sumsat)
#     print("standard error is", sterr)

    plt.rcParams["figure.figsize"] = [15, 8]
    fig = plt.figure()
    ax = fig.add_subplot(111)
#     plt.title("Histogram of the Number of Satellite Galaxies; log(lum)=10.36; 0.55 < z < 0.6", fontsize=25)
#     plt.title("Histogram of the Number of Satellite Galaxies; log(lum)={}; {} < z < {}".format(lum, z1, z2), fontsize=20)
    plt.title("Number of LRGs with Significant Satellite Detections (bootstrap); log(lum)={}; {} < z < {}".format(lum, z1, z2), fontsize=16)
    plt.hist(sumsat, bins=50)
#     plt.axvline(linewidth=1, color='r')
#     plt.xlabel(r'$Number$ $of$ $Satellite$ $Galaxies$', fontsize=25)
    plt.xlabel(r'$Number$ $of$ $LRGs$ $with$ $Significant$ $Satellite$ $Detections$', fontsize=16)
    plt.ylabel(r'$counts$', fontsize=25)
    plt.axvline(x=ci_l, linewidth=1, ls='-', color='r')
    plt.axvline(x=ci_u, linewidth=1, ls='-', color='r')
    plt.text(top, right,'mean = {}'.format(meansat), fontsize=14, ha='center', va='center', transform=ax.transAxes)
#     plt.text(top, right-0.05,'median = {}'.format(mediansat), fontsize=14, ha='center', va='center', transform=ax.transAxes)
    plt.text(top, right-0.1,'stdev = {}'.format(sdsat), fontsize=14, ha='center', va='center', transform=ax.transAxes)
    # plt.show()
#     return(sumsat)

# %%
# # bootstrap with resampling from masked Nsat

# from astropy.stats import bootstrap

# # sumsat_lowz25, sats_lowz25, nosats_lowz25 = sigSats(lowz_newNsat25, p25_low[2])

# sumsat = []
# # Sum up number of satellite galaxies for every LRG
# for i in range(len(lowz_newNsat25)):
#     sumsat.append(np.sum(lowz_newNsat25[i]))

# print(len(sumsat))
# # print(len(sats_lowz25))
# # print(len(nosats_lowz25))

# # sumsat is an array of the number of satellites around each LRG. array is length of number of LRGs.
# # result of bootstrap should be bootnum number of resampling with replacement
# # low_bootstrap25 = bootstrap(np.array(lowz_newNsat25), bootnum=5000)
# low_bootstrap25 = bootstrap(np.array(sumsat), bootnum=5000)
# print(low_bootstrap25.shape)

# print("first")

# %%
# bootstrap with resampling from low 

from astropy.stats import bootstrap

sumsat35_low = []
# Sum up number of satellite galaxies for every LRG
for i in range(len(Nsat35_low)):
    sumsat35_low.append(np.sum(Nsat35_low[i]))

print(len(sumsat35_low))
# print(len(sats_lowz25))
# print(len(nosats_lowz25))

# sumsat is an array of the number of satellites around each LRG. array is length of number of LRGs.
# result of bootstrap should be bootnum number of resampling with replacement
low_bootstrap35 = bootstrap(np.array(sumsat35_low), bootnum=5000)
# print(low_bootstrap25.shape)
# print(low_bootstrap25[4])

print("first")

# next, determine how many of these are above the 99 percent threshold
# this gives an array of indices of LRGs with sats and without sats
low_sats35 = []
low_nosats35 = []
# low_sumsats25 = []
for i in range(len(low_bootstrap35)):
    sats_list, nosats_list = sigSats_usingSumsat(low_bootstrap35[i], plow35[2])
    low_sats35.append(sats_list)
    low_nosats35.append(nosats_list)
    
# print(np.asarray(low_sats25[4]))
# print('----')
# print(len(np.asarray(low_nosats25)))

print("second")


# calculate percentage of LRGs have a significant satellite population
low_percent35 = []
for i in range(len(low_sats35)):
    temp = (len(low_sats35[i])/len(sumsat35_low))*100.
    low_percent35.append(temp)

# print(low_percent25)

print("third")

# # next, use the length of each sats array to find out how many LRGs in the sample have
# # a significant satellite population
# low_num_with_sats25 = []
# for i in range(len(low_sats25)):
#     low_num_with_sats25.append(len(low_sats25[i]))
                               
# print(low_num_with_sats25)

# print("fourth")

# calculate 68 percent confidece interval
low_ci_l_35, low_ci_u_35 = confidence_interval(low_percent35)
print('lower confidence limit: ', low_ci_l_35)
print('upper confidence limit: ', low_ci_u_35)

print("fourth")

totalNsat(low_percent35, 9.27, round(zrange[0], 2), round(zrange[1], 2), low_ci_l_35, low_ci_u_35)

# plt.savefig('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/lowz_LRG_with_sats25.pdf')
plt.show()
# Out:
# 309
# first
# second
# third
# lower confidence limit:  5.361156132503103
# upper confidence limit:  8.223568786590748
# fourth

# %%
# bootstrap with resampling from mid35 

from astropy.stats import bootstrap

sumsat35_mid = []
# Sum up number of satellite galaxies for every LRG
for i in range(len(Nsat35_mid)):
    sumsat35_mid.append(np.sum(Nsat35_mid[i]))

print(len(sumsat35_mid))
# print(len(sats_lowz25))
# print(len(nosats_lowz25))

# sumsat is an array of the number of satellites around each LRG. array is length of number of LRGs.
# result of bootstrap should be bootnum number of resampling with replacement
mid_bootstrap35 = bootstrap(np.array(sumsat35_mid), bootnum=5000)
# print(low_bootstrap25.shape)
# print(low_bootstrap25[4])

print("first")

# next, determine how many of these are above the 99 percent threshold
# this gives an array of indices of LRGs with sats and without sats
mid_sats35 = []
mid_nosats35 = []
# low_sumsats25 = []
for i in range(len(mid_bootstrap35)):
    sats_list, nosats_list = sigSats_usingSumsat(mid_bootstrap35[i], pmid35[2])
    mid_sats35.append(sats_list)
    mid_nosats35.append(nosats_list)
    
# print(np.asarray(low_sats25[4]))
# print('----')
# print(len(np.asarray(low_nosats25)))

print("second")


# calculate percentage of LRGs have a significant satellite population
mid_percent35 = []
for i in range(len(mid_sats35)):
    temp = (len(mid_sats35[i])/len(sumsat35_mid))*100.
    mid_percent35.append(temp)

# print(low_percent25)

print("third")

# # next, use the length of each sats array to find out how many LRGs in the sample have
# # a significant satellite population
# low_num_with_sats25 = []
# for i in range(len(low_sats25)):
#     low_num_with_sats25.append(len(low_sats25[i]))
                               
# print(low_num_with_sats25)

# print("fourth")

# calculate 68 percent confidece interval
mid_ci_l_35, mid_ci_u_35 = confidence_interval(mid_percent35)
print('lower confidence limit: ', mid_ci_l_35)
print('upper confidence limit: ', mid_ci_u_35)

print("fourth")

totalNsat(mid_percent35, 9.58, round(zrange[0], 2), round(zrange[1], 2), mid_ci_l_35, mid_ci_u_35)

# plt.savefig('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/lowz_LRG_with_sats25.pdf')
plt.show()


# print(mid_percent35)
print(np.std(mid_percent35))
# Out:
# 309
# first
# second
# third
# lower confidence limit:  5.36079748538974
# upper confidence limit:  8.200497012992138
# fourth
# 1.4198497638011986

# %%
# bootstrap with resampling from mid05

from astropy.stats import bootstrap

sumsat05_mid = []
# Sum up number of satellite galaxies for every LRG
for i in range(len(Nsat05_mid)):
    sumsat05_mid.append(np.sum(Nsat05_mid[i]))

print(len(sumsat05_mid))
# print(len(sats_lowz25))
# print(len(nosats_lowz25))

# sumsat is an array of the number of satellites around each LRG. array is length of number of LRGs.
# result of bootstrap should be bootnum number of resampling with replacement
mid_bootstrap05 = bootstrap(np.array(sumsat05_mid), bootnum=5000)
# print(low_bootstrap25.shape)
# print(low_bootstrap25[4])

print("first")

# next, determine how many of these are above the 99 percent threshold
# this gives an array of indices of LRGs with sats and without sats
mid_sats05 = []
mid_nosats05 = []
# low_sumsats25 = []
for i in range(len(mid_bootstrap05)):
    sats_list, nosats_list = sigSats_usingSumsat(mid_bootstrap05[i], pmid05[2])
    mid_sats05.append(sats_list)
    mid_nosats05.append(nosats_list)
    
# print(np.asarray(low_sats25[4]))
# print('----')
# print(len(np.asarray(low_nosats25)))

print("second")


# calculate percentage of LRGs have a significant satellite population
mid_percent05 = []
for i in range(len(mid_sats05)):
    temp = (len(mid_sats05[i])/len(sumsat05_mid))*100.
    mid_percent05.append(temp)

# print(low_percent25)

print("third")

# # next, use the length of each sats array to find out how many LRGs in the sample have
# # a significant satellite population
# low_num_with_sats25 = []
# for i in range(len(low_sats25)):
#     low_num_with_sats25.append(len(low_sats25[i]))
                               
# print(low_num_with_sats25)

# print("fourth")

# calculate 68 percent confidece interval
mid_ci_l_05, mid_ci_u_05 = confidence_interval(mid_percent05)
print('lower confidence limit: ', mid_ci_l_05)
print('upper confidence limit: ', mid_ci_u_05)

print("fourth")

totalNsat(mid_percent05, 9.58, round(zrange[1], 2), round(zrange[2], 2), mid_ci_l_05, mid_ci_u_05)

# plt.savefig('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/lowz_LRG_with_sats25.pdf')
plt.show()

print(np.std(mid_percent05))
# Out:
# 617
# first
# second
# third
# lower confidence limit:  1.2550758338388257
# upper confidence limit:  2.3205481531952104
# fourth
# 0.5327361596781924

# %%
# bootstrap with resampling from high35 

from astropy.stats import bootstrap

sumsat35_high = []
# Sum up number of satellite galaxies for every LRG
for i in range(len(Nsat35_high)):
    sumsat35_high.append(np.sum(Nsat35_high[i]))

print(len(sumsat35_high))
# print(len(sats_lowz25))
# print(len(nosats_lowz25))

# sumsat is an array of the number of satellites around each LRG. array is length of number of LRGs.
# result of bootstrap should be bootnum number of resampling with replacement
high_bootstrap35 = bootstrap(np.array(sumsat35_high), bootnum=5000)
# print(low_bootstrap25.shape)
# print(low_bootstrap25[4])

print("first")

# next, determine how many of these are above the 99 percent threshold
# this gives an array of indices of LRGs with sats and without sats
high_sats35 = []
high_nosats35 = []
# low_sumsats25 = []
for i in range(len(high_bootstrap35)):
    sats_list, nosats_list = sigSats_usingSumsat(high_bootstrap35[i], phigh35[2])
    high_sats35.append(sats_list)
    high_nosats35.append(nosats_list)
    
# print(np.asarray(low_sats25[4]))
# print('----')
# print(len(np.asarray(low_nosats25)))

print("second")


# calculate percentage of LRGs have a significant satellite population
high_percent35 = []
for i in range(len(high_sats35)):
    temp = (len(high_sats35[i])/len(sumsat35_high))*100.
    high_percent35.append(temp)

# print(low_percent25)

print("third")

# # next, use the length of each sats array to find out how many LRGs in the sample have
# # a significant satellite population
# low_num_with_sats25 = []
# for i in range(len(low_sats25)):
#     low_num_with_sats25.append(len(low_sats25[i]))
                               
# print(low_num_with_sats25)

# print("fourth")

# calculate 68 percent confidece interval
high_ci_l_35, high_ci_u_35 = confidence_interval(high_percent35)
print('lower confidence limit: ', high_ci_l_35)
print('upper confidence limit: ', high_ci_u_35)

print("fourth")

totalNsat(high_percent35, 9.85, round(zrange[0], 2), round(zrange[1], 2), high_ci_l_35, high_ci_u_35)

# plt.savefig('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/lowz_LRG_with_sats25.pdf')
plt.show()
# Out:
# 309
# first
# second
# third
# lower confidence limit:  1.7196656721313426
# upper confidence limit:  3.5119200883864563
# fourth

# %%
# bootstrap with resampling from high05

from astropy.stats import bootstrap

sumsat05_high = []
# Sum up number of satellite galaxies for every LRG
for i in range(len(Nsat05_high)):
    sumsat05_high.append(np.sum(Nsat05_high[i]))

print(len(sumsat05_high))
# print(len(sats_lowz25))
# print(len(nosats_lowz25))

# sumsat is an array of the number of satellites around each LRG. array is length of number of LRGs.
# result of bootstrap should be bootnum number of resampling with replacement
high_bootstrap05 = bootstrap(np.array(sumsat05_high), bootnum=5000)
# print(low_bootstrap25.shape)
# print(low_bootstrap25[4])

print("first")

# next, determine how many of these are above the 99 percent threshold
# this gives an array of indices of LRGs with sats and without sats
high_sats05 = []
high_nosats05 = []
# low_sumsats25 = []
for i in range(len(high_bootstrap05)):
    sats_list, nosats_list = sigSats_usingSumsat(high_bootstrap05[i], phigh05[2])
    high_sats05.append(sats_list)
    high_nosats05.append(nosats_list)
    
# print(np.asarray(low_sats25[4]))
# print('----')
# print(len(np.asarray(low_nosats25)))

print("second")


# calculate percentage of LRGs have a significant satellite population
high_percent05 = []
for i in range(len(high_sats05)):
    temp = (len(high_sats05[i])/len(sumsat05_high))*100.
    high_percent05.append(temp)

# print(low_percent25)

print("third")

# # next, use the length of each sats array to find out how many LRGs in the sample have
# # a significant satellite population
# low_num_with_sats25 = []
# for i in range(len(low_sats25)):
#     low_num_with_sats25.append(len(low_sats25[i]))
                               
# print(low_num_with_sats25)

# print("fourth")

# calculate 68 percent confidece interval
high_ci_l_05, high_ci_u_05 = confidence_interval(high_percent05)
print('lower confidence limit: ', high_ci_l_05)
print('upper confidence limit: ', high_ci_u_05)

print("fourth")

totalNsat(high_percent05, 9.85, round(zrange[1], 2), round(zrange[2], 2), high_ci_l_05, high_ci_u_05)

# plt.savefig('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/lowz_LRG_with_sats25.pdf')
plt.show()
# Out:
# 617
# first
# second
# third
# lower confidence limit:  1.3902577462416468
# upper confidence limit:  2.504912432040363
# fourth

# %%
# bootstrap with resampling from high65

from astropy.stats import bootstrap

sumsat65_high = []
# Sum up number of satellite galaxies for every LRG
for i in range(len(Nsat65_high)):
    sumsat65_high.append(np.sum(Nsat65_high[i]))

print(len(sumsat65_high))
# print(len(sats_lowz25))
# print(len(nosats_lowz25))

# sumsat is an array of the number of satellites around each LRG. array is length of number of LRGs.
# result of bootstrap should be bootnum number of resampling with replacement
high_bootstrap65 = bootstrap(np.array(sumsat65_high), bootnum=5000)
# print(low_bootstrap25.shape)
# print(low_bootstrap25[4])

print("first")

# next, determine how many of these are above the 99 percent threshold
# this gives an array of indices of LRGs with sats and without sats
high_sats65 = []
high_nosats65 = []
# low_sumsats25 = []
for i in range(len(high_bootstrap65)):
    sats_list, nosats_list = sigSats_usingSumsat(high_bootstrap65[i], phigh65[2])
    high_sats65.append(sats_list)
    high_nosats65.append(nosats_list)
    
# print(np.asarray(low_sats25[4]))
# print('----')
# print(len(np.asarray(low_nosats25)))

print("second")


# calculate percentage of LRGs have a significant satellite population
high_percent65 = []
for i in range(len(high_sats65)):
    temp = (len(high_sats65[i])/len(sumsat65_high))*100.
    high_percent65.append(temp)

# print(low_percent25)

print("third")

# # next, use the length of each sats array to find out how many LRGs in the sample have
# # a significant satellite population
# low_num_with_sats25 = []
# for i in range(len(low_sats25)):
#     low_num_with_sats25.append(len(low_sats25[i]))
                               
# print(low_num_with_sats25)

# print("fourth")

# calculate 68 percent confidece interval
high_ci_l_65, high_ci_u_65 = confidence_interval(high_percent65)
print('lower confidence limit: ', high_ci_l_65)
print('upper confidence limit: ', high_ci_u_65)

print("fourth")

totalNsat(high_percent65, 9.85, round(zrange[2], 2), round(zrange[3], 2), high_ci_l_65, high_ci_u_65)

# plt.savefig('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/lowz_LRG_with_sats25.pdf')
plt.show()
# Out:
# 897
# first
# second
# third
# lower confidence limit:  1.2506744013586564
# upper confidence limit:  2.0955909275153677
# fourth

# %%
# # bootstrap with resampling from masked Nsat03

# from astropy.stats import bootstrap

# low_sumsat03 = []
# # Sum up number of satellite galaxies for every LRG
# for i in range(len(lowz_newNsat03)):
#     low_sumsat03.append(np.sum(lowz_newNsat03[i]))

# print(len(low_sumsat03))
# # print(len(sats_lowz25))
# # print(len(nosats_lowz25))

# # sumsat is an array of the number of satellites around each LRG. array is length of number of LRGs.
# # result of bootstrap should be bootnum number of resampling with replacement
# low_bootstrap03 = bootstrap(np.array(low_sumsat03), bootnum=5000)
# # print(low_bootstrap25.shape)
# # print(low_bootstrap25[4])

# print("first")

# # next, determine how many of these are above the 99 percent threshold
# # this gives an array of indices of LRGs with sats and without sats
# low_sats03 = []
# low_nosats03 = []
# for i in range(len(low_bootstrap03)):
#     sats_list, nosats_list = sigSats_usingSumsat(low_bootstrap03[i], p30_low[2])
#     low_sats03.append(sats_list)
#     low_nosats03.append(nosats_list)
    
# # print(np.asarray(low_sats25[4]))
# # print('----')
# # print(len(np.asarray(low_nosats25)))

# print("second")


# # calculate percentage of LRGs have a significant satellite population
# low_percent03 = []
# for i in range(len(low_sats03)):
#     temp = (len(low_sats03[i])/len(low_sumsat03))*100.
#     low_percent03.append(temp)

# # print(low_percent25)

# print("third")

# # # next, use the length of each sats array to find out how many LRGs in the sample have
# # # a significant satellite population
# # low_num_with_sats25 = []
# # for i in range(len(low_sats25)):
# #     low_num_with_sats25.append(len(low_sats25[i]))
                               
# # print(low_num_with_sats25)

# # print("fourth")

# # calculate 68 percent confidece interval
# low_ci_l_03, low_ci_u_03 = confidence_interval(low_percent03)
# print('lower confidence limit: ', low_ci_l_03)
# print('upper confidence limit: ', low_ci_u_03)

# print("fourth")

# totalNsat(low_percent03, 9.55, round(zrange[1], 2), round(zrange[2], 2), low_ci_l_03, low_ci_u_03)

# # plt.savefig('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/lowz_LRG_with_sats25.pdf')
# plt.show()

# %%
# save confidence limits for plotting

# np.savez('/Users/mtownsend/Documents/LRG_Data/ci_lower-EDR.npz', low35=low_ci_l_35, mid35=mid_ci_l_35, mid05=mid_ci_l_05, high35=high_ci_l_35, high05=high_ci_l_05, high65=high_ci_l_65)
data_l = np.load('/Users/mtownsend/Documents/LRG_Data/ci_lower-EDR.npz')
low35_l = data_l['low35']
mid35_l = data_l['mid35']
mid05_l = data_l['mid05']
high35_l = data_l['high35']
high05_l = data_l['high05']
high65_l = data_l['high65']

print(low35_l)
print()
print(mid35_l)
print(mid05_l)
print()
print(high35_l)
print(high05_l)
print(high65_l)

print()
print()

# np.savez('/Users/mtownsend/Documents/LRG_Data/ci_upper-EDR.npz', low35=low_ci_u_35, mid35=mid_ci_u_35, mid05=mid_ci_u_05, high35=high_ci_u_35, high05=high_ci_u_05, high65=high_ci_u_65)
data_u = np.load('/Users/mtownsend/Documents/LRG_Data/ci_upper-EDR.npz')
low35_u = data_u['low35']
mid35_u = data_u['mid35']
mid05_u = data_u['mid05']
high35_u = data_u['high35']
high05_u = data_u['high05']
high65_u = data_u['high65']

print(low35_u)
print()
print(mid35_u)
print(mid05_u)
print()
print(high35_u)
print(high05_u)
print(high65_u)
# Out:
# 5.361156132503103
#
# 5.36079748538974
# 1.2550758338388257
#
# 1.7196656721313426
# 1.3902577462416468
# 1.2506744013586564
#
#
# 8.223568786590748
#
# 8.200497012992138
# 2.3205481531952104
#
# 3.5119200883864563
# 2.504912432040363
# 2.0955909275153677

# %%
# print(np.array(high_sats65).shape)
# print(high_sats65[0])
print(len(mid_percent05))
print(np.array(mid_percent05).shape)
# print(high_percent65[578])

print(high_bootstrap05.shape)

# %%
sumsat_low35, sats_low35, nosats_low35 = sigSats(Nsat35_low, plow35[2])
print(len(sats_low35))
print(sats_low35)

print()

sumsat_mid35, sats_mid35, nosats_low35 = sigSats(Nsat35_mid, pmid35[2])
print(len(sats_mid35))
print(sats_mid35)
print()
sumsat_mid05, sats_mid05, nosats_mid05 = sigSats(Nsat05_mid, pmid05[2])

sumsat_high35, sats_high35, nosats_high35 = sigSats(Nsat35_high, phigh35[2])
print(len(sats_high35))
print(sats_high35)
print()
sumsat_high05, sats_high05, nosats_high05 = sigSats(Nsat05_high, phigh05[2])
sumsat_high65, sats_high65, nosats_high65 = sigSats(Nsat65_high, phigh65[2])


print(np.intersect1d(sats_low35, sats_high35))
print(np.intersect1d(sats_mid35, sats_high35))
# Out:
# 21
# [0, 11, 23, 24, 69, 71, 74, 76, 78, 164, 174, 204, 233, 236, 237, 250, 251, 267, 283, 288, 300]
#
# 21
# [11, 22, 24, 69, 71, 74, 76, 148, 163, 164, 174, 204, 231, 234, 236, 237, 250, 251, 267, 283, 300]
#
# 8
# [71, 74, 164, 174, 204, 236, 237, 300]
#
# [ 71  74 164 174 204 236 237 300]
# [ 71  74 164 174 204 236 237 300]

# %%
print(sats_low35[0:5])
print(nosats_low35[0:5])

print(len(sats_low35))

# %%
low_percent35_ = len(sats_low35)/len(sumsat_low35)*100.
print(len(sats_low35))
# print(len(sumsat_low35))
print(low_percent35_)
ytop_low35 = low35_u - low_percent35_
ybot_low35 = low_percent35_ - low35_l
yerr_low35 = np.array(([ybot_low35, ytop_low35]))

print(yerr_low35)
print()

# print(low_percent35)

# print()

# print(low35_l)

# print(low35_u)

mid_percent35_ = len(sats_mid35)/len(sumsat_mid35)*100.
print(len(sats_mid35))
# print(len(sumsat_mid35))
# print(mid_percent35_)
mid_percent05_ = len(sats_mid05)/len(sumsat_mid05)*100.
# print(mid_percent05_)
print(len(sats_mid05))

mid_percent = [mid_percent35_, mid_percent05_]
print(mid_percent)

ytop_mid35 = mid35_u - mid_percent35_
ybot_mid35 = mid_percent35_ - mid35_l
yerr_mid35 = np.array(([ybot_mid35, ytop_mid35]))

print(yerr_mid35)
print()

ytop_mid05 = mid05_u - mid_percent05_
ybot_mid05 = mid_percent05_ - mid05_l
yerr_mid05 = np.array(([ybot_mid05, ytop_mid05]))

print(yerr_mid05)


yerr_midbot = np.array([ybot_mid35, ybot_mid05])
yerr_midtop = np.array([ytop_mid35, ytop_mid05])

# print(mid_percent35)
# print()
# print(mid35_l)
# print(mid35_u)

# print()
# print()

# print(mid_percent05)
# print()
# print(mid05_l)
# print(mid05_u)


high_percent35_ = len(sats_high35)/len(sumsat_high35)*100.
print(len(sats_high35))
high_percent05_ = len(sats_high05)/len(sumsat_high05)*100.
print(len(sats_high05))
high_percent65_ = len(sats_high65)/len(sumsat_high65)*100.
print(len(sats_high65))

high_percent = [high_percent35_, high_percent05_, high_percent65_]
print(high_percent)

ytop_high35 = high35_u - high_percent35_
ybot_high35 = high_percent35_ - high35_l
yerr_high35 = np.array(([ybot_high35, ytop_high35]))

print(yerr_high35)

ytop_high05 = high05_u - high_percent05_
ybot_high05 = high_percent05_ - high05_l
yerr_high05 = np.array(([ybot_high05, ytop_high05]))

print(yerr_high05)

ytop_high65 = high65_u - high_percent65_
ybot_high65 = high_percent65_ - high65_l
yerr_high65 = np.array(([ybot_high65, ytop_high65]))

print(yerr_high65)

yerr_bot = np.array([ybot_high35, ybot_high05, ybot_high65])
yerr_top = np.array([ytop_high35, ytop_high05, ytop_high65])

# print(yerr_bot)
# print(yerr_top)

# print(high_percent35)
# print()
# print(high35_l)
# print(high35_u)

# print()
# print()

# print(high_percent05)
# print()
# print(high05_l)
# print(high05_u)

# print()
# print()

# print(high_percent65)
# print()
# print(high65_l)
# print(high65_u)

redshift_low = [0.274]
redshift_mid = [0.2795, 0.423]
redshift_high = [0.277, 0.4295, 0.577]

fig, ax = plt.subplots(1, 1, figsize=(15,10))
ax.errorbar(redshift_low, low_percent35_, ecolor='blue', ls='none', yerr=[yerr_low35])
ax.scatter(redshift_low, low_percent35_, color='blue', marker='o', s=1000, label='log$_{10}(L_g/L_\odot$) $\geq$ 9.27')
# ax.errorbar(redshift_low, low_percent35_, ecolor='blue', ls='none', yerr=[yerr_low35])

ax.scatter(redshift_mid, mid_percent, color='red', marker='*', s=1000, label='log$_{10}(L_g/L_\odot$) $\geq$ 9.58')
# ax.errorbar(redshift_mid, mid_percent, ecolor='red', ls='none', yerr=[yerr_mid35, yerr_mid05])
ax.vlines(redshift_mid, mid_percent-yerr_midbot, mid_percent+yerr_midtop, color='red')

ax.scatter(redshift_high, high_percent, color='green', marker='^', s=1000, label='log$_{10}(L_g/L_\odot$) $\geq$ 9.85')
# ax.errorbar(redshift_high, high_percent, ecolor='green', ls='none', yerr=[yerr_high35, yerr_high05, yerr_high65])
ax.vlines(redshift_high, high_percent-yerr_bot, high_percent+yerr_top, color='green')

ax.legend(fontsize='25', markerscale=0.75)

ax.set_xlabel(r'redshift', fontsize=30)
ax.set_ylabel(r'percentage', fontsize=30)
ax.xaxis.set_tick_params(labelsize=25)
ax.yaxis.set_tick_params(labelsize=25)

plt.savefig('/Users/mtownsend/Desktop/PaperPlots/oneplot-EDR-v5.pdf')

plt.show()
# Out:
# 21
# 6.796116504854369
# [1.43496037 1.42745228]
#
# 21
# 11
# [6.796116504854369, 1.7828200972447326]
# [1.43531902 1.40438051]
#
# [0.52774426 0.53772806]
# 8
# 12
# 15
# [2.5889967637540456, 1.9448946515397085, 1.6722408026755853]
# [0.86933109 0.92292332]
# [0.55463691 0.56001778]
# [0.4215664  0.42335012]

# %%
mid35_std = np.std(mid_percent35_)
# print(mid35_std)
mid05_std = np.std(mid_percent05_)
# print(mid05_std)

high35_std = np.std(high_percent35_)
high05_std = np.std(high_percent05_)
high65_std = np.std(high_percent65_)

# significance of the difference between mid points

sod_mid = (mid_percent35_ - mid_percent05_) / (np.sqrt(mid35_std**2. + mid05_std**2))
print(sod_mid)

# significance of the difference between first two high points

sod_high = (high_percent35_ - high_percent05_) / (np.sqrt(high35_std**2. + high05_std**2))
print(sod_high)


# 0.8516058856614661
# 0.3240813608295349
# 1.774689910780354
# 2.8123455138514935
# Out:
# inf
# inf
# /Users/mtownsend/anaconda/envs/astroconda/lib/python3.5/site-packages/ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in double_scalars
#   if sys.path[0] == '':
# /Users/mtownsend/anaconda/envs/astroconda/lib/python3.5/site-packages/ipykernel_launcher.py:17: RuntimeWarning: divide by zero encountered in double_scalars

# %%
# plot only LRGs that have an excess of satellites

# %%
# lowz
# masked_Nsat_low35 = Nsat_bin1_new * low_smatrix35

# np.savez('/Users/mtownsend/Documents/LRG_Data/masked_Nsat_low-EDR.npz', masked_Nsat_low35=masked_Nsat_low35)
data_Nsat_low = np.load('/Users/mtownsend/Documents/LRG_Data/masked_Nsat_low-EDR.npz')
Nsat35_low_new = data_Nsat_low['masked_Nsat_low35']
print(len(Nsat35_low_new))

# midz
# masked_Nsat_mid35 = Nsat_bin1_new * mid_smatrix35
# masked_Nsat_mid05 = Nsat_bin2_new * mid_smatrix05

# np.savez('/Users/mtownsend/Documents/LRG_Data/masked_Nsat_mid-EDR.npz', masked_Nsat_mid35=masked_Nsat_mid35, masked_Nsat_mid05=masked_Nsat_mid05)
data_Nsat_mid = np.load('/Users/mtownsend/Documents/LRG_Data/masked_Nsat_mid-EDR.npz')
Nsat35_mid_new = data_Nsat_mid['masked_Nsat_mid35']
Nsat05_mid_new = data_Nsat_mid['masked_Nsat_mid05']
print(len(Nsat35_mid_new))
print(len(Nsat05_mid_new))

# highz
# masked_Nsat_high35 = Nsat_bin1_new * high_smatrix35
# masked_Nsat_high05 = Nsat_bin2_new * high_smatrix05
# masked_Nsat_high65 = Nsat_bin3_new * high_smatrix65

# np.savez('/Users/mtownsend/Documents/LRG_Data/masked_Nsat_high-EDR.npz', masked_Nsat_high35=masked_Nsat_high35, masked_Nsat_high05=masked_Nsat_high05, masked_Nsat_high65=masked_Nsat_high65)
data_Nsat_high = np.load('/Users/mtownsend/Documents/LRG_Data/masked_Nsat_high-EDR.npz')
Nsat35_high_new = data_Nsat_high['masked_Nsat_high35']
Nsat05_high_new = data_Nsat_high['masked_Nsat_high05']
Nsat65_high_new = data_Nsat_high['masked_Nsat_high65']
print(len(Nsat35_high_new))
print(len(Nsat05_high_new))
print(len(Nsat65_high_new))


data_zLRG = np.load('/Users/mtownsend/anaconda/Data/z_LRG.npz')
zLRG = data_zLRG['z_LRG']
print(zLRG.shape)

zLRG_low = zLRG[np.where((zLRG >= 0.2) & (zLRG < 0.35))]
print(len(zLRG_low))
zLRG_mid = zLRG[np.where((zLRG >= 0.35) & (zLRG < 0.5))]
print(len(zLRG_mid))
zLRG_high = zLRG[np.where((zLRG >= 0.5) & (zLRG < 0.65))]
print(len(zLRG_high))


# sats_low35

# sats_mid35
# sats_mid05

# sats_high35
# sats_high05
# sats_high65
# Out:
# 309
# 309
# 617
# 309
# 617
# 897
# (1823,)
# 309
# 617
# 897

# %%
sumsat_low35, sats_low35, nosats_low35 = sigSats(Nsat35_low, plow35[2])

sumsat_mid35, sats_mid35, nosats_low35 = sigSats(Nsat35_mid, pmid35[2])
sumsat_mid05, sats_mid05, nosats_mid05 = sigSats(Nsat05_mid, pmid05[2])

sumsat_high35, sats_high35, nosats_high35 = sigSats(Nsat35_high, phigh35[2])
sumsat_high05, sats_high05, nosats_high05 = sigSats(Nsat05_high, phigh05[2])
print(sats_high05)
sumsat_high65, sats_high65, nosats_high65 = sigSats(Nsat65_high, phigh65[2])
# Out:
# [12, 142, 155, 157, 170, 182, 285, 318, 340, 341, 350, 354]

# %%
# sumsat_low35, sats_low35, nosats_low35 = sigSats(Nsat35_low, plow35[2])

# sumsat_mid35, sats_mid35, nosats_low35 = sigSats(Nsat35_mid, pmid35[2])
# sumsat_mid05, sats_mid05, nosats_mid05 = sigSats(Nsat05_mid, pmid05[2])

# sumsat_high35, sats_high35, nosats_high35 = sigSats(Nsat35_high, phigh35[2])
# sumsat_high05, sats_high05, nosats_high05 = sigSats(Nsat05_high, phigh05[2])
# sumsat_high65, sats_high65, nosats_high65 = sigSats(Nsat65_high, phigh65[2])
    
    
sumsat_low_35 = np.array([sumsat_low35]).flatten()

sumsat_mid_35 = np.array([sumsat_mid35]).flatten()
sumsat_mid_05 = np.array([sumsat_mid05]).flatten()

sumsat_high_35 = np.array([sumsat_high35]).flatten()
sumsat_high_05 = np.array([sumsat_high05]).flatten()
sumsat_high_65 = np.array([sumsat_high65]).flatten()
    
    
# plt.scatter(zLRG_low[sats_low35], sumsat_low_35[sats_low35], color='blue', marker='o', s=50, label='log(lum) > 9.5; 0.2 < z < 0.35')
# plt.legend(fontsize='xx-large', markerscale=0.75)
# plt.show()

# plt.scatter(zLRG_mid[sats_mid35], sumsat_mid_35[sats_mid35], color='red', marker='*', s=50, label='log(lum) > 9.93; 0.2 < z < 0.5')
# plt.scatter(zLRG_mid[sats_mid05], sumsat_mid_05[sats_mid05], color='red', marker='*', s=50)
# plt.legend(fontsize='xx-large', markerscale=0.75)
# plt.show()

# plt.scatter(zLRG_high[sats_high35], sumsat_high_35[sats_high35], color='green', marker='^', s=50, label='log(lum) > 10.27; 0.2 < z < 0.65')
# plt.scatter(zLRG_high[sats_high05], sumsat_high_05[sats_high05], color='green', marker='^', s=50)
# plt.scatter(zLRG_high[sats_high05], sumsat_high_05[sats_high05], color='green', marker='^', s=50)
# plt.legend(fontsize='xx-large', markerscale=0.75)
# plt.show()

fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3, figsize = (36,18))

ax1.scatter(zLRG_low, sumsat_low_35, color='blue', marker='o', s=50, label='$log_{10}(L)$ > 9.27; 0.2 < z < 0.35')
ax1.axhline(y=plow35[2], color='black', linestyle= '-.')
ax1.legend(fontsize='xx-large', markerscale=0.75, loc='upper right')
ax1.text(0.32, 14.2, '99th percentile = {}'.format(round(plow35[2],2), fontsize=50))
ax1.set_xlabel('redshift', fontsize=15)
ax1.set_ylabel('satellite numbers', fontsize=15)
ax1.tick_params(axis='both', which='major', labelsize=12)
# plt.show()

ax2.scatter(zLRG_low, sumsat_mid_35, color='red', marker='*', s=50, label='$log_{10}(L)$ > 9.58; 0.2 < z < 0.35')
ax2.axhline(y=pmid35[2], color='black', linestyle= '-.')
ax2.legend(fontsize='xx-large', markerscale=0.75, loc='upper right')
ax2.text(0.32, 9.33, '99th percentile = {}'.format(round(pmid35[2],2), fontsize=24))
ax2.set_xlabel('redshift', fontsize=15)
ax2.set_ylabel('satellite numbers', fontsize=15)
ax2.tick_params(axis='both', which='major', labelsize=12)
# plt.show()

ax3.scatter(zLRG_mid, sumsat_mid_05, color='red', marker='*', s=50, label='$log_{10}(L)$ > 9.58; 0.35 < z < 0.5')
ax3.axhline(y=pmid05[2], color='black', linestyle= '-.')
ax3.legend(fontsize='xx-large', markerscale=0.75, loc='upper right')
ax3.text(0.46, 12.49, '99th percentile = {}'.format(round(pmid05[2],2), fontsize=24))
ax3.set_xlabel('redshift', fontsize=15)
ax3.set_ylabel('satellite numbers', fontsize=15)
ax3.tick_params(axis='both', which='major', labelsize=12)
# plt.show()

ax4.scatter(zLRG_low, sumsat_high_35, color='green', marker='^', s=50, label='$log_{10}(L)$ > 9.85; 0.2 < z < 0.35')
ax4.axhline(y=phigh35[2], color='black', linestyle= '-.')
ax4.legend(fontsize='xx-large', markerscale=0.75, loc='upper right')
ax4.text(0.32, 6.3, '99th percentile = {}'.format(round(phigh35[2],2), fontsize=24))
ax4.set_xlabel('redshift', fontsize=15)
ax4.set_ylabel('satellite numbers', fontsize=15)
ax4.tick_params(axis='both', which='major', labelsize=12)
# plt.show()

ax5.scatter(zLRG_mid, sumsat_high_05, color='green', marker='^', s=50, label='$log_{10}(L)$ > 9.85; 0.35 < z < 0.5')
ax5.axhline(y=phigh05[2], color='black', linestyle= '-.')
ax5.legend(fontsize='xx-large', markerscale=0.75, loc='upper right')
ax5.text(0.46, 7.2, '99th percentile = {}'.format(round(phigh05[2],2), fontsize=24))
ax5.set_xlabel('redshift', fontsize=15)
ax5.set_ylabel('satellite numbers', fontsize=15)
ax5.tick_params(axis='both', which='major', labelsize=12)
# plt.show()

ax6.scatter(zLRG_high, sumsat_high_65, color='green', marker='^', s=50, label='$log_{10}(L)$ > 9.85; 0.5 < z < 0.65')
ax6.axhline(y=phigh65[2], color='black', linestyle= '-.')
ax6.legend(fontsize='xx-large', markerscale=0.75, loc='upper right')
ax6.text(0.6, 12.41, '99th percentile = {}'.format(round(phigh65[2],2), fontsize=24))
ax6.set_xlabel('redshift', fontsize=15)
ax6.set_ylabel('satellite numbers', fontsize=15)
ax6.tick_params(axis='both', which='major', labelsize=12)
# plt.show()

# plt.xlabel('redshift', fontsize=15)
# plt.ylabel('satellite numbers', fontsize=15)
# plt.tick_params(axis='both', which='major', labelsize=12)
# plt.savefig('/Users/mtownsend/Desktop/PaperPlots/sats_v_redshift-v2.pdf')

plt.show()

# %%
# fig, ax = plt.subplots(1, 1, figsize=(15,10))
# ax.scatter(redshift_low, low_percent35_, color='blue', marker='o', s=1000, label='log(lum) > 9.5; 0.2 < z < 0.35')
# ax.errorbar(redshift_low, low_percent35_, ecolor='blue', ls='none', yerr=[yerr_low35])

# ax.scatter(redshift_mid, mid_percent, color='red', marker='*', s=1000, label='log(lum) > 9.93; 0.2 < z < 0.5')
# # ax.errorbar(redshift_mid, mid_percent, ecolor='red', ls='none', yerr=[yerr_mid35, yerr_mid05])
# ax.vlines(redshift_mid, mid_percent-yerr_midbot, mid_percent+yerr_midtop, color='red')

# ax.scatter(redshift_high, high_percent, color='green', marker='^', s=1000, label='log(lum) > 10.27; 0.2 < z < 0.65')
# # ax.errorbar(redshift_high, high_percent, ecolor='green', ls='none', yerr=[yerr_high35, yerr_high05, yerr_high65])
# ax.vlines(redshift_high, high_percent-yerr_bot, high_percent+yerr_top, color='green')

# ax.legend(fontsize='xx-large', markerscale=0.75)

# ax.set_xlabel(r'$redshift$', fontsize=25)
# ax.set_ylabel(r'$percentage$', fontsize=25)
# ax.xaxis.set_tick_params(labelsize=20)
# ax.yaxis.set_tick_params(labelsize=20)

# # plt.savefig('/Users/mtownsend/Desktop/PaperPlots/oneplot-EDR.pdf')

# plt.show()
