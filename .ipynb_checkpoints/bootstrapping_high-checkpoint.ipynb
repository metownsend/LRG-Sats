# %%
from astropy.io import fits
from astropy.table import Table
import numpy as np
import matplotlib.pylab as plt 
import matplotlib.lines as mlines
from matplotlib.legend import Legend
from pythonds.basic.stack import Stack
from math import *
from sklearn.neighbors import KDTree
from lrg_plot_functions import *
from lrg_sum_functions import *
from cosmo_Calc import *
from divideByTwo import *
from read_data import *
from nearNeighbors import *
from scipy import stats
from astropy import stats
import healpy as hp
from localBKG_and_interlopersHEALPix import *
# import healpy as hpy
from makeCutoutTableFunc import *
from plotHistogramProjections3D import *
from read_bricks import *
from mpl_toolkits.axes_grid1 import make_axes_locatable
import random
from sigSats import *
from sigSats_usingSumsat import *
from confidence_interval import *

# %%
# read in Nsat data divvied up into diferent redshift bins


data_Nsat25 = np.load('/Users/mtownsend/Documents/LRG_Data/data_Nsat25_unmasked.npz')
Nsat25 = data_Nsat25['Nsat25']
print(Nsat25.shape)

print('----')

data_Nsat03 = np.load('/Users/mtownsend/Documents/LRG_Data/data_Nsat03_unmasked.npz')
Nsat03 = data_Nsat03['Nsat03']
print(Nsat03.shape)

print('----')

data_Nsat35 = np.load('/Users/mtownsend/Documents/LRG_Data/data_Nsat35_unmasked.npz')
Nsat35 = data_Nsat35['Nsat35']
print(Nsat35.shape)

print('----')

data_Nsat04 = np.load('/Users/mtownsend/Documents/LRG_Data/data_Nsat04_unmasked.npz')
Nsat04 = data_Nsat04['Nsat04']
print(Nsat04.shape)

print('----')

data_Nsat45 = np.load('/Users/mtownsend/Documents/LRG_Data/data_Nsat45_unmasked.npz')
Nsat45 = data_Nsat45['Nsat45']
print(Nsat45.shape)

print('----')

data_Nsat05 = np.load('/Users/mtownsend/Documents/LRG_Data/data_Nsat05_unmasked.npz')
Nsat05 = data_Nsat05['Nsat05']
print(Nsat05.shape)

print('----')

data_Nsat55 = np.load('/Users/mtownsend/Documents/LRG_Data/data_Nsat55_unmasked.npz')
Nsat55 = data_Nsat55['Nsat55']
print(Nsat55.shape)

print('----')

data_Nsat06 = np.load('/Users/mtownsend/Documents/LRG_Data/data_Nsat06_unmasked.npz')
Nsat06 = data_Nsat06['Nsat06']
print(Nsat06.shape)

print('----')

data_Nsat65 = np.load('/Users/mtownsend/Documents/LRG_Data/data_Nsat65_unmasked.npz')
Nsat65 = data_Nsat65['Nsat65']
print(Nsat65.shape)

print('----')

zinit = 0.2
zfin = 0.65
interval = 0.05
# num = (zfin-zinit)/interval
num = 10. 
zrange, step = np.linspace(zinit, zfin, num=int(num), retstep=True)
print(zrange)
# Out:
# (90, 49, 49, 49)
# ----
# (83, 49, 49, 49)
# ----
# (136, 49, 49, 49)
# ----
# (128, 49, 49, 49)
# ----
# (180, 49, 49, 49)
# ----
# (309, 49, 49, 49)
# ----
# (386, 49, 49, 49)
# ----
# (325, 49, 49, 49)
# ----
# (186, 49, 49, 49)
# ----
# [0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65]

# %%
# read in selection matrices for each luminosity selected sample 

data_smatrix65 = np.load('/Users/mtownsend/Desktop/highz_smatrix-9matrices.npz')
smatrix65 = data_smatrix65['smatrix_low']
print(smatrix65.shape)
# Out:
# (9, 49, 49, 49)

# %%
# read in files with the number of satellites for 80, 90, and 99 percentiles for each LRG redshift/luminosity bin

percentiles_highz = np.load('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/percentiles_high.npz')
p25_high = percentiles_highz['p25_high']
p30_high = percentiles_highz['p30_high']
p35_high = percentiles_highz['p35_high']
p40_high = percentiles_highz['p40_high']
p45_high = percentiles_highz['p45_high']
p50_high = percentiles_highz['p50_high']
p55_high = percentiles_highz['p55_high']
p60_high = percentiles_highz['p60_high']
p65_high = percentiles_highz['p65_high']

# %%
# def totalNsat(Nsat, lum, z1, z2):
# def totalNsat(sumsat, lum, z1, z2):
def totalNsat(sumsat, lum, z1, z2, ci_l, ci_u):

    import matplotlib.pylab as plt 	
    import numpy as np
    from scipy import stats
    
    left, width = .25, .5
    bottom, height = .25, .5
    right = left + width
    top = bottom + height


#     sumsat = []

#     # Sum up number of satellite galaxies for every LRG
#     for i in range(len(Nsat)):
#         sumsat.append(np.sum(Nsat[i]))

    meansat = np.mean(sumsat)
#     print("mean number of satellites is", meansat)
    
    mediansat = np.median(sumsat)
#     print("median number of satellites is", mediansat)

    sdsat = np.std(sumsat)
#     print("standard deviation of satellites is", sdsat)

    sterr = stats.sem(sumsat)
#     print("standard error is", sterr)

    plt.rcParams["figure.figsize"] = [15, 8]
    fig = plt.figure()
    ax = fig.add_subplot(111)
#     plt.title("Histogram of the Number of Satellite Galaxies; log(lum)=10.36; 0.55 < z < 0.6", fontsize=25)
#     plt.title("Histogram of the Number of Satellite Galaxies; log(lum)={}; {} < z < {}".format(lum, z1, z2), fontsize=20)
    plt.title("Number of LRGs with Significant Satellite Detections (bootstrap); log(lum)={}; {} < z < {}".format(lum, z1, z2), fontsize=16)
    plt.hist(sumsat, bins=50)
#     plt.axvline(linewidth=1, color='r')
#     plt.xlabel(r'$Number$ $of$ $Satellite$ $Galaxies$', fontsize=25)
    plt.xlabel(r'$Number$ $of$ $LRGs$ $with$ $Significant$ $Satellite$ $Detections$', fontsize=16)
    plt.ylabel(r'$counts$', fontsize=25)
    plt.axvline(x=ci_l, linewidth=1, ls='-', color='r')
    plt.axvline(x=ci_u, linewidth=1, ls='-', color='r')
    plt.text(top, right,'mean = {}'.format(meansat), fontsize=14, ha='center', va='center', transform=ax.transAxes)
#     plt.text(top, right-0.05,'median = {}'.format(mediansat), fontsize=14, ha='center', va='center', transform=ax.transAxes)
    plt.text(top, right-0.1,'stdev = {}'.format(sdsat), fontsize=14, ha='center', va='center', transform=ax.transAxes)
    # plt.show()
#     return(sumsat)

# %%
# make new Nsat for log(lum)=10.47; 0.2 < z < 0.65

# 0.2 < z < 0.25
high_newNsat25 = []
for i in range(len(Nsat25)):
    high_newNsat25.append(Nsat25[i] * smatrix65[0])
    
# 0.25 < z < 0.3
high_newNsat03 = []
for i in range(len(Nsat03)):
    high_newNsat03.append(Nsat03[i] * smatrix65[1])
    
# 0.3 < z < 0.35
high_newNsat35 = []
for i in range(len(Nsat35)):
    high_newNsat35.append(Nsat35[i] * smatrix65[2])
    
# 0.35 < z < 0.4
high_newNsat04 = []
for i in range(len(Nsat04)):
    high_newNsat04.append(Nsat04[i] * smatrix65[3])
    
# 0.4 < z < 0.45
high_newNsat45 = []
for i in range(len(Nsat45)):
    high_newNsat45.append(Nsat45[i] * smatrix65[4])
    
# 0.45 < z < 0.5
high_newNsat05 = []
for i in range(len(Nsat05)):
    high_newNsat05.append(Nsat05[i] * smatrix65[5])
    
# 0.5 < z < 0.55
high_newNsat55 = []
for i in range(len(Nsat55)):
    high_newNsat55.append(Nsat55[i] * smatrix65[6])
    
# 0.55 < z < 0.6
high_newNsat06 = []
for i in range(len(Nsat06)):
    high_newNsat06.append(Nsat06[i] * smatrix65[7])

# 0.6 < z < 0.65
high_newNsat65 = []
for i in range(len(Nsat65)):
    high_newNsat65.append(Nsat65[i] * smatrix65[8])


print(np.asarray(high_newNsat25).shape)
print(np.asarray(high_newNsat03).shape)
print(np.asarray(high_newNsat35).shape)
print(np.asarray(high_newNsat04).shape)
print(np.asarray(high_newNsat45).shape)
print(np.asarray(high_newNsat05).shape)
print(np.asarray(high_newNsat55).shape)
print(np.asarray(high_newNsat06).shape)
print(np.asarray(high_newNsat65).shape)
# Out:
# (90, 49, 49, 49)
# (83, 49, 49, 49)
# (136, 49, 49, 49)
# (128, 49, 49, 49)
# (180, 49, 49, 49)
# (309, 49, 49, 49)
# (386, 49, 49, 49)
# (325, 49, 49, 49)
# (186, 49, 49, 49)

# %%
# bootstrap with resampling from masked Nsat25

from astropy.stats import bootstrap

high_sumsat25 = []
# Sum up number of satellite galaxies for every LRG
for i in range(len(high_newNsat25)):
    high_sumsat25.append(np.sum(high_newNsat25[i]))

print(len(high_sumsat25))
# print(len(sats_lowz25))
# print(len(nosats_lowz25))

# sumsat is an array of the number of satellites around each LRG. array is length of number of LRGs.
# result of bootstrap should be bootnum number of resampling with replacement
high_bootstrap25 = bootstrap(np.array(high_sumsat25), bootnum=5000)
# print(low_bootstrap25.shape)
# print(low_bootstrap25[4])

print("first")

# next, determine how many of these are above the 99 percent threshold
# this gives an array of indices of LRGs with sats and without sats
high_sats25 = []
high_nosats25 = []
# low_sumsats25 = []
for i in range(len(high_bootstrap25)):
    sats_list, nosats_list = sigSats_usingSumsat(high_bootstrap25[i], p25_high[2])
    high_sats25.append(sats_list)
    high_nosats25.append(nosats_list)
    
# print(np.asarray(low_sats25[4]))
# print('----')
# print(len(np.asarray(low_nosats25)))

print("second")


# calculate percentage of LRGs have a significant satellite population
high_percent25 = []
for i in range(len(high_sats25)):
    temp = (len(high_sats25[i])/len(high_sumsat25))*100.
    high_percent25.append(temp)

# print(low_percent25)

print("third")

# # next, use the length of each sats array to find out how many LRGs in the sample have
# # a significant satellite population
# low_num_with_sats25 = []
# for i in range(len(low_sats25)):
#     low_num_with_sats25.append(len(low_sats25[i]))
                               
# print(low_num_with_sats25)

# print("fourth")

# calculate 68 percent confidece interval
high_ci_l_25, high_ci_u_25 = confidence_interval(high_percent25)
print('lower confidence limit: ', high_ci_l_25)
print('upper confidence limit: ', high_ci_u_25)

print("fourth")

totalNsat(high_percent25, 10.47, round(zrange[0], 2), round(zrange[1], 2), high_ci_l_25, high_ci_u_25)

# plt.savefig('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/lowz_LRG_with_sats25.pdf')
plt.show()
# Out:
# 90
# first
# second
# third
# lower confidence limit:  0.0
# upper confidence limit:  0.0
# fourth

# %%
# bootstrap with resampling from masked Nsat03

from astropy.stats import bootstrap

high_sumsat03 = []
# Sum up number of satellite galaxies for every LRG
for i in range(len(high_newNsat03)):
    high_sumsat03.append(np.sum(high_newNsat03[i]))

print(len(high_sumsat03))
# print(len(sats_lowz25))
# print(len(nosats_lowz25))

# sumsat is an array of the number of satellites around each LRG. array is length of number of LRGs.
# result of bootstrap should be bootnum number of resampling with replacement
high_bootstrap03 = bootstrap(np.array(high_sumsat03), bootnum=5000)
# print(low_bootstrap25.shape)
# print(low_bootstrap25[4])

print("first")

# next, determine how many of these are above the 99 percent threshold
# this gives an array of indices of LRGs with sats and without sats
high_sats03 = []
high_nosats03 = []
# low_sumsats25 = []
for i in range(len(high_bootstrap03)):
    sats_list, nosats_list = sigSats_usingSumsat(high_bootstrap03[i], p30_high[2])
    high_sats03.append(sats_list)
    high_nosats03.append(nosats_list)
    
# print(np.asarray(low_sats25[4]))
# print('----')
# print(len(np.asarray(low_nosats25)))

print("second")


# calculate percentage of LRGs have a significant satellite population
high_percent03 = []
for i in range(len(high_sats03)):
    temp = (len(high_sats03[i])/len(high_sumsat03))*100.
    high_percent03.append(temp)

# print(low_percent25)

print("third")

# # next, use the length of each sats array to find out how many LRGs in the sample have
# # a significant satellite population
# low_num_with_sats25 = []
# for i in range(len(low_sats25)):
#     low_num_with_sats25.append(len(low_sats25[i]))
                               
# print(low_num_with_sats25)

# print("fourth")

# calculate 68 percent confidece interval
high_ci_l_03, high_ci_u_03 = confidence_interval(high_percent03)
print('lower confidence limit: ', high_ci_l_03)
print('upper confidence limit: ', high_ci_u_03)

print("fourth")

totalNsat(high_percent03, 10.47, round(zrange[1], 2), round(zrange[2], 2), high_ci_l_03, high_ci_u_03)

# plt.savefig('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/lowz_LRG_with_sats25.pdf')
plt.show()
# Out:
# 83
# first
# second
# third
# lower confidence limit:  0.0
# upper confidence limit:  0.0
# fourth

# %%
# bootstrap with resampling from masked Nsat35

from astropy.stats import bootstrap

high_sumsat35 = []
# Sum up number of satellite galaxies for every LRG
for i in range(len(high_newNsat35)):
    high_sumsat35.append(np.sum(high_newNsat35[i]))

print(len(high_sumsat35))
# print(len(sats_lowz25))
# print(len(nosats_lowz25))

# sumsat is an array of the number of satellites around each LRG. array is length of number of LRGs.
# result of bootstrap should be bootnum number of resampling with replacement
high_bootstrap35 = bootstrap(np.array(high_sumsat35), bootnum=5000)
# print(low_bootstrap25.shape)
# print(low_bootstrap25[4])

print("first")

# next, determine how many of these are above the 99 percent threshold
# this gives an array of indices of LRGs with sats and without sats
high_sats35 = []
high_nosats35 = []
# low_sumsats25 = []
for i in range(len(high_bootstrap35)):
    sats_list, nosats_list = sigSats_usingSumsat(high_bootstrap35[i], p35_high[2])
    high_sats35.append(sats_list)
    high_nosats35.append(nosats_list)
    
# print(np.asarray(low_sats25[4]))
# print('----')
# print(len(np.asarray(low_nosats25)))

print("second")


# calculate percentage of LRGs have a significant satellite population
high_percent35 = []
for i in range(len(high_sats35)):
    temp = (len(high_sats35[i])/len(high_sumsat35))*100.
    high_percent35.append(temp)

# print(low_percent25)

print("third")

# # next, use the length of each sats array to find out how many LRGs in the sample have
# # a significant satellite population
# low_num_with_sats25 = []
# for i in range(len(low_sats25)):
#     low_num_with_sats25.append(len(low_sats25[i]))
                               
# print(low_num_with_sats25)

# print("fourth")

# calculate 68 percent confidece interval
high_ci_l_35, high_ci_u_35 = confidence_interval(high_percent35)
print('lower confidence limit: ', high_ci_l_35)
print('upper confidence limit: ', high_ci_u_35)

print("fourth")

totalNsat(high_percent35, 10.47, round(zrange[2], 2), round(zrange[3], 2), high_ci_l_35, high_ci_u_35)

# plt.savefig('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/lowz_LRG_with_sats25.pdf')
plt.show()
# Out:
# 136
# first
# second
# third
# lower confidence limit:  0.9368695126091704
# upper confidence limit:  3.516071663861418
# fourth

# %%
# bootstrap with resampling from masked Nsat04

from astropy.stats import bootstrap

high_sumsat04 = []
# Sum up number of satellite galaxies for every LRG
for i in range(len(high_newNsat04)):
    high_sumsat04.append(np.sum(high_newNsat04[i]))

print(len(high_sumsat04))
# print(len(sats_lowz25))
# print(len(nosats_lowz25))

# sumsat is an array of the number of satellites around each LRG. array is length of number of LRGs.
# result of bootstrap should be bootnum number of resampling with replacement
high_bootstrap04 = bootstrap(np.array(high_sumsat04), bootnum=5000)
# print(low_bootstrap25.shape)
# print(low_bootstrap25[4])

print("first")

# next, determine how many of these are above the 99 percent threshold
# this gives an array of indices of LRGs with sats and without sats
high_sats04 = []
high_nosats04 = []
# low_sumsats25 = []
for i in range(len(high_bootstrap04)):
    sats_list, nosats_list = sigSats_usingSumsat(high_bootstrap04[i], p40_high[2])
    high_sats04.append(sats_list)
    high_nosats04.append(nosats_list)
    
# print(np.asarray(low_sats25[4]))
# print('----')
# print(len(np.asarray(low_nosats25)))

print("second")


# calculate percentage of LRGs have a significant satellite population
high_percent04 = []
for i in range(len(high_sats04)):
    temp = (len(high_sats04[i])/len(high_sumsat04))*100.
    high_percent04.append(temp)

# print(low_percent25)

print("third")

# # next, use the length of each sats array to find out how many LRGs in the sample have
# # a significant satellite population
# low_num_with_sats25 = []
# for i in range(len(low_sats25)):
#     low_num_with_sats25.append(len(low_sats25[i]))
                               
# print(low_num_with_sats25)

# print("fourth")

# calculate 68 percent confidece interval
high_ci_l_04, high_ci_u_04 = confidence_interval(high_percent04)
print('lower confidence limit: ', high_ci_l_04)
print('upper confidence limit: ', high_ci_u_04)

print("fourth")

totalNsat(high_percent04, 10.47, round(zrange[3], 2), round(zrange[4], 2), high_ci_l_04, high_ci_u_04)

# plt.savefig('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/lowz_LRG_with_sats25.pdf')
plt.show()
# Out:
# 128
# first
# second
# third
# lower confidence limit:  0.4405800067670569
# upper confidence limit:  2.6447324932329432
# fourth

# %%
# bootstrap with resampling from masked Nsat45

from astropy.stats import bootstrap

high_sumsat45 = []
# Sum up number of satellite galaxies for every LRG
for i in range(len(high_newNsat45)):
    high_sumsat45.append(np.sum(high_newNsat45[i]))

print(len(high_sumsat45))
# print(len(sats_lowz25))
# print(len(nosats_lowz25))

# sumsat is an array of the number of satellites around each LRG. array is length of number of LRGs.
# result of bootstrap should be bootnum number of resampling with replacement
high_bootstrap45 = bootstrap(np.array(high_sumsat45), bootnum=5000)
# print(low_bootstrap25.shape)
# print(low_bootstrap25[4])

print("first")

# next, determine how many of these are above the 99 percent threshold
# this gives an array of indices of LRGs with sats and without sats
high_sats45 = []
high_nosats45 = []
# low_sumsats25 = []
for i in range(len(high_bootstrap45)):
    sats_list, nosats_list = sigSats_usingSumsat(high_bootstrap45[i], p45_high[2])
    high_sats45.append(sats_list)
    high_nosats45.append(nosats_list)
    
# print(np.asarray(low_sats25[4]))
# print('----')
# print(len(np.asarray(low_nosats25)))

print("second")


# calculate percentage of LRGs have a significant satellite population
high_percent45 = []
for i in range(len(high_sats45)):
    temp = (len(high_sats45[i])/len(high_sumsat45))*100.
    high_percent45.append(temp)

# print(low_percent25)

print("third")

# # next, use the length of each sats array to find out how many LRGs in the sample have
# # a significant satellite population
# low_num_with_sats25 = []
# for i in range(len(low_sats25)):
#     low_num_with_sats25.append(len(low_sats25[i]))
                               
# print(low_num_with_sats25)

# print("fourth")

# calculate 68 percent confidece interval
high_ci_l_45, high_ci_u_45 = confidence_interval(high_percent45)
print('lower confidence limit: ', high_ci_l_45)
print('upper confidence limit: ', high_ci_u_45)

print("fourth")

totalNsat(high_percent45, 10.47, round(zrange[4], 2), round(zrange[5], 2), high_ci_l_45, high_ci_u_45)

# plt.savefig('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/lowz_LRG_with_sats25.pdf')
plt.show()
# Out:
# 180
# first
# second
# third
# lower confidence limit:  -0.0032171193674129794
# upper confidence limit:  1.1121060082563021
# fourth

# %%
# bootstrap with resampling from masked Nsat05

from astropy.stats import bootstrap

high_sumsat05 = []
# Sum up number of satellite galaxies for every LRG
for i in range(len(high_newNsat05)):
    high_sumsat05.append(np.sum(high_newNsat05[i]))

print(len(high_sumsat05))
# print(len(sats_lowz25))
# print(len(nosats_lowz25))

# sumsat is an array of the number of satellites around each LRG. array is length of number of LRGs.
# result of bootstrap should be bootnum number of resampling with replacement
high_bootstrap05 = bootstrap(np.array(high_sumsat05), bootnum=5000)
# print(low_bootstrap25.shape)
# print(low_bootstrap25[4])

print("first")

# next, determine how many of these are above the 99 percent threshold
# this gives an array of indices of LRGs with sats and without sats
high_sats05 = []
high_nosats05 = []
# low_sumsats25 = []
for i in range(len(high_bootstrap05)):
    sats_list, nosats_list = sigSats_usingSumsat(high_bootstrap05[i], p50_high[2])
    high_sats05.append(sats_list)
    high_nosats05.append(nosats_list)
    
# print(np.asarray(low_sats25[4]))
# print('----')
# print(len(np.asarray(low_nosats25)))

print("second")


# calculate percentage of LRGs have a significant satellite population
high_percent05 = []
for i in range(len(high_sats05)):
    temp = (len(high_sats05[i])/len(high_sumsat05))*100.
    high_percent05.append(temp)

# print(low_percent25)

print("third")

# # next, use the length of each sats array to find out how many LRGs in the sample have
# # a significant satellite population
# low_num_with_sats25 = []
# for i in range(len(low_sats25)):
#     low_num_with_sats25.append(len(low_sats25[i]))
                               
# print(low_num_with_sats25)

# print("fourth")

# calculate 68 percent confidece interval
high_ci_l_05, high_ci_u_05 = confidence_interval(high_percent05)
print('lower confidence limit: ', high_ci_l_05)
print('upper confidence limit: ', high_ci_u_05)

print("fourth")

totalNsat(high_percent05, 10.47, round(zrange[5], 2), round(zrange[6], 2), high_ci_l_05, high_ci_u_05)

# plt.savefig('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/lowz_LRG_with_sats25.pdf')
plt.show()
# Out:
# 309
# first
# second
# third
# lower confidence limit:  -0.00022917967534680228
# upper confidence limit:  0.6382874321025314
# fourth

# %%
# bootstrap with resampling from masked Nsat55

from astropy.stats import bootstrap

high_sumsat55 = []
# Sum up number of satellite galaxies for every LRG
for i in range(len(high_newNsat55)):
    high_sumsat55.append(np.sum(high_newNsat55[i]))

print(len(high_sumsat55))
# print(len(sats_lowz25))
# print(len(nosats_lowz25))

# sumsat is an array of the number of satellites around each LRG. array is length of number of LRGs.
# result of bootstrap should be bootnum number of resampling with replacement
high_bootstrap55 = bootstrap(np.array(high_sumsat55), bootnum=5000)
# print(low_bootstrap25.shape)
# print(low_bootstrap25[4])

print("first")

# next, determine how many of these are above the 99 percent threshold
# this gives an array of indices of LRGs with sats and without sats
high_sats55 = []
high_nosats55 = []
# low_sumsats25 = []
for i in range(len(high_bootstrap55)):
    sats_list, nosats_list = sigSats_usingSumsat(high_bootstrap55[i], p55_high[2])
    high_sats55.append(sats_list)
    high_nosats55.append(nosats_list)
    
# print(np.asarray(low_sats25[4]))
# print('----')
# print(len(np.asarray(low_nosats25)))

print("second")


# calculate percentage of LRGs have a significant satellite population
high_percent55 = []
for i in range(len(high_sats55)):
    temp = (len(high_sats55[i])/len(high_sumsat55))*100.
    high_percent55.append(temp)

# print(low_percent25)

print("third")

# # next, use the length of each sats array to find out how many LRGs in the sample have
# # a significant satellite population
# low_num_with_sats25 = []
# for i in range(len(low_sats25)):
#     low_num_with_sats25.append(len(low_sats25[i]))
                               
# print(low_num_with_sats25)

# print("fourth")

# calculate 68 percent confidece interval
high_ci_l_55, high_ci_u_55 = confidence_interval(high_percent55)
print('lower confidence limit: ', high_ci_l_55)
print('upper confidence limit: ', high_ci_u_55)

print("fourth")

totalNsat(high_percent55, 10.47, round(zrange[6], 2), round(zrange[7], 2), high_ci_l_55, high_ci_u_55)

# plt.savefig('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/lowz_LRG_with_sats25.pdf')
plt.show()
# Out:
# 386
# first
# second
# third
# lower confidence limit:  0.334377877915091
# upper confidence limit:  1.2188863707895723
# fourth

# %%
# bootstrap with resampling from masked Nsat06

from astropy.stats import bootstrap

high_sumsat06 = []
# Sum up number of satellite galaxies for every LRG
for i in range(len(high_newNsat06)):
    high_sumsat06.append(np.sum(high_newNsat06[i]))

print(len(high_sumsat55))
# print(len(sats_lowz25))
# print(len(nosats_lowz25))

# sumsat is an array of the number of satellites around each LRG. array is length of number of LRGs.
# result of bootstrap should be bootnum number of resampling with replacement
high_bootstrap06 = bootstrap(np.array(high_sumsat06), bootnum=5000)
# print(low_bootstrap25.shape)
# print(low_bootstrap25[4])

print("first")

# next, determine how many of these are above the 99 percent threshold
# this gives an array of indices of LRGs with sats and without sats
high_sats06 = []
high_nosats06 = []
# low_sumsats25 = []
for i in range(len(high_bootstrap06)):
    sats_list, nosats_list = sigSats_usingSumsat(high_bootstrap06[i], p60_high[2])
    high_sats06.append(sats_list)
    high_nosats06.append(nosats_list)
    
# print(np.asarray(low_sats25[4]))
# print('----')
# print(len(np.asarray(low_nosats25)))

print("second")


# calculate percentage of LRGs have a significant satellite population
high_percent06 = []
for i in range(len(high_sats06)):
    temp = (len(high_sats06[i])/len(high_sumsat06))*100.
    high_percent06.append(temp)

# print(low_percent25)

print("third")

# # next, use the length of each sats array to find out how many LRGs in the sample have
# # a significant satellite population
# low_num_with_sats25 = []
# for i in range(len(low_sats25)):
#     low_num_with_sats25.append(len(low_sats25[i]))
                               
# print(low_num_with_sats25)

# print("fourth")

# calculate 68 percent confidece interval
high_ci_l_06, high_ci_u_06 = confidence_interval(high_percent06)
print('lower confidence limit: ', high_ci_l_06)
print('upper confidence limit: ', high_ci_u_06)

print("fourth")

totalNsat(high_percent06, 10.47, round(zrange[7], 2), round(zrange[8], 2), high_ci_l_06, high_ci_u_06)

# plt.savefig('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/lowz_LRG_with_sats25.pdf')
plt.show()
# Out:
# 386
# first
# second
# third
# lower confidence limit:  0.4040718753215712
# upper confidence limit:  1.472358893909198
# fourth

# %%
# bootstrap with resampling from masked Nsat65

from astropy.stats import bootstrap

high_sumsat65 = []
# Sum up number of satellite galaxies for every LRG
for i in range(len(high_newNsat65)):
    high_sumsat65.append(np.sum(high_newNsat65[i]))

print(len(high_sumsat65))
# print(len(sats_lowz25))
# print(len(nosats_lowz25))

# sumsat is an array of the number of satellites around each LRG. array is length of number of LRGs.
# result of bootstrap should be bootnum number of resampling with replacement
high_bootstrap65 = bootstrap(np.array(high_sumsat65), bootnum=5000)
# print(low_bootstrap25.shape)
# print(low_bootstrap25[4])

print("first")

# next, determine how many of these are above the 99 percent threshold
# this gives an array of indices of LRGs with sats and without sats
high_sats65 = []
high_nosats65 = []
# low_sumsats25 = []
for i in range(len(high_bootstrap65)):
    sats_list, nosats_list = sigSats_usingSumsat(high_bootstrap65[i], p65_high[2])
    high_sats65.append(sats_list)
    high_nosats65.append(nosats_list)
    
# print(np.asarray(low_sats25[4]))
# print('----')
# print(len(np.asarray(low_nosats25)))

print("second")


# calculate percentage of LRGs have a significant satellite population
high_percent65 = []
for i in range(len(high_sats65)):
    temp = (len(high_sats65[i])/len(high_sumsat65))*100.
    high_percent65.append(temp)

# print(low_percent25)

print("third")

# # next, use the length of each sats array to find out how many LRGs in the sample have
# # a significant satellite population
# low_num_with_sats25 = []
# for i in range(len(low_sats25)):
#     low_num_with_sats25.append(len(low_sats25[i]))
                               
# print(low_num_with_sats25)

# print("fourth")

# calculate 68 percent confidece interval
high_ci_l_65, high_ci_u_65 = confidence_interval(high_percent65)
print('lower confidence limit: ', high_ci_l_65)
print('upper confidence limit: ', high_ci_u_65)

print("fourth")

totalNsat(high_percent65, 10.47, round(zrange[8], 2), round(zrange[9], 2), high_ci_l_65, high_ci_u_65)

# plt.savefig('/Users/mtownsend/Desktop/MeetingPlots/2Oct2020/lowz_LRG_with_sats25.pdf')
plt.show()
# Out:
# 186
# first
# second
# third
# lower confidence limit:  0.007660368798422024
# upper confidence limit:  1.0858880182983521
# fourth

# %%
# save confidence limits for plotting

np.savez('/Users/mtownsend/Documents/LRG_Data/high_ci_lower.npz', high_lower_25=high_ci_l_25, high_lower_03=high_ci_l_03, high_lower_35=high_ci_l_35, high_lower_04=high_ci_l_04, high_lower_45=high_ci_l_45, high_lower_05=high_ci_l_05, high_lower_55=high_ci_l_55, high_lower_06=high_ci_l_06, high_lower_65=high_ci_l_65)
data = np.load('/Users/mtownsend/Documents/LRG_Data/high_ci_lower.npz')
print(data['high_lower_25'])
print(data['high_lower_03'])
print(data['high_lower_35'])
print(data['high_lower_04'])
print(data['high_lower_45'])
print(data['high_lower_05'])
print(data['high_lower_55'])
print(data['high_lower_06'])
print(data['high_lower_65'])

np.savez('/Users/mtownsend/Documents/LRG_Data/high_ci_upper.npz', high_upper_25=high_ci_u_25, high_upper_03=high_ci_u_03, high_upper_35=high_ci_u_35, high_upper_04=high_ci_u_04, high_upper_45=high_ci_u_45, high_upper_05=high_ci_u_05, high_upper_55=high_ci_u_55, high_upper_06=high_ci_u_06, high_upper_65=high_ci_u_65)
data = np.load('/Users/mtownsend/Documents/LRG_Data/high_ci_upper.npz')
print(data['high_upper_25'])
print(data['high_upper_03'])
print(data['high_upper_35'])
print(data['high_upper_04'])
print(data['high_upper_45'])
print(data['high_upper_05'])
print(data['high_upper_55'])
print(data['high_upper_06'])
print(data['high_upper_65'])
# Out:
# 0.0
# 0.0
# 0.9368695126091704
# 0.4405800067670569
# -0.0032171193674129794
# -0.00022917967534680228
# 0.334377877915091
# 0.4040718753215712
# 0.007660368798422024
# 0.0
# 0.0
# 3.516071663861418
# 2.6447324932329432
# 1.1121060082563021
# 0.6382874321025314
# 1.2188863707895723
# 1.472358893909198
# 1.0858880182983521
