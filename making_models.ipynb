# %%
from astropy.io import fits
from astropy.table import Table
import numpy as np
import matplotlib.pylab as plt 
import matplotlib.lines as mlines
from matplotlib.legend import Legend
from pythonds.basic.stack import Stack
from math import *
from sklearn.neighbors import KDTree
from lrg_plot_functions import *
from lrg_sum_functions import *
from cosmo_Calc import *
from divideByTwo import *
from read_data import *
from nearNeighbors import *
from scipy import stats
from astropy import stats
import healpy as hp
from localBKG_and_interlopersHEALPix import *
# import healpy as hpy
from makeCutoutTableFunc import *
from plotHistogramProjections3D import *
from read_bricks import *
from mpl_toolkits.axes_grid1 import make_axes_locatable
import random

# %%
# read in models

# 0.2 < z < 0.35

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model1_output-EDR.npz', new_rz35_1=new_rz35_1, new_gr35_1=new_gr35_1, new_zmag35_1=new_zmag35_1, new_index35_1=new_index35_1, new_alt_index35_1=new_alt_index35_1)
# data_model35_1 = np.load('/Users/mtownsend/Documents/LRG_Data/low35_model1_output-EDR.npz')
# data_model35_1 = np.load('/Users/mtownsend/Documents/LRG_Data/mid35_model1_output-EDR.npz')
data_model35_1 = np.load('/Users/mtownsend/Documents/LRG_Data/high35_model1_output-EDR.npz')
rzNew35_1 = data_model35_1['new_rz35_1']
grNew35_1 = data_model35_1['new_gr35_1']
zmagNew35_1 = data_model35_1['new_zmag35_1']

print(len(rzNew35_1))
print(len(grNew35_1))
print(len(zmagNew35_1))

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model2_output-EDR.npz', new_rz35_2=new_rz35_2, new_gr35_2=new_gr35_2, new_zmag35_2=new_zmag35_2, new_index35_2=new_index35_2, new_alt_index35_2=new_alt_index35_2)
# data_model35_2 = np.load('/Users/mtownsend/Documents/LRG_Data/low35_model2_output-EDR.npz')
# data_model35_2 = np.load('/Users/mtownsend/Documents/LRG_Data/mid35_model2_output-EDR.npz')
data_model35_2 = np.load('/Users/mtownsend/Documents/LRG_Data/high35_model2_output-EDR.npz')
rzNew35_2 = data_model35_2['new_rz35_2']
grNew35_2 = data_model35_2['new_gr35_2']
zmagNew35_2 = data_model35_2['new_zmag35_2']

print(len(rzNew35_2))
print(len(grNew35_2))
print(len(zmagNew35_2))

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model3_output-EDR.npz', new_rz35_3=new_rz35_3, new_gr35_3=new_gr35_3, new_zmag35_3=new_zmag35_3, new_index35_3=new_index35_3, new_alt_index35_3=new_alt_index35_3)
# data_model35_3 = np.load('/Users/mtownsend/Documents/LRG_Data/low35_model3_output-EDR.npz')
# data_model35_3 = np.load('/Users/mtownsend/Documents/LRG_Data/mid35_model3_output-EDR.npz')
data_model35_3 = np.load('/Users/mtownsend/Documents/LRG_Data/high35_model3_output-EDR.npz')
rzNew35_3 = data_model35_3['new_rz35_3']
grNew35_3 = data_model35_3['new_gr35_3']
zmagNew35_3 = data_model35_3['new_zmag35_3']

print(len(rzNew35_3))
print(len(grNew35_3))
print(len(zmagNew35_3))

# np.savez('/Users/mtownsend/Documents/LRG_Data/low35_model4_output-EDR.npz', new_rz35_4=new_rz35_4, new_gr35_4=new_gr35_4, new_zmag35_4=new_zmag35_4, new_index35_4=new_index35_4, new_alt_index35_4=new_alt_index35_4)
# data_model35_4 = np.load('/Users/mtownsend/Documents/LRG_Data/low35_model4_output-EDR.npz')
# data_model35_4 = np.load('/Users/mtownsend/Documents/LRG_Data/mid35_model4_output-EDR.npz')
data_model35_4 = np.load('/Users/mtownsend/Documents/LRG_Data/high35_model4_output-EDR.npz')
rzNew35_4 = data_model35_4['new_rz35_4']
grNew35_4 = data_model35_4['new_gr35_4']
zmagNew35_4 = data_model35_4['new_zmag35_4']

print(len(rzNew35_4))
print(len(grNew35_4))
print(len(zmagNew35_4))

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model5_output-EDR.npz', new_rz35_5=new_rz35_5, new_gr35_5=new_gr35_5, new_zmag35_5=new_zmag35_5, new_index35_5=new_index35_5, new_alt_index35_5=new_alt_index35_5)
# data_model35_5 = np.load('/Users/mtownsend/Documents/LRG_Data/low35_model5_output-EDR.npz')
# data_model35_5 = np.load('/Users/mtownsend/Documents/LRG_Data/mid35_model5_output-EDR.npz')
data_model35_5 = np.load('/Users/mtownsend/Documents/LRG_Data/high35_model5_output-EDR.npz')
rzNew35_5 = data_model35_5['new_rz35_5']
grNew35_5 = data_model35_5['new_gr35_5']
zmagNew35_5 = data_model35_5['new_zmag35_5']

print(len(rzNew35_5))
print(len(grNew35_5))
print(len(zmagNew35_5))

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model6_output-EDR.npz', new_rz35_6=new_rz35_6, new_gr35_6=new_gr35_6, new_zmag35_6=new_zmag35_6, new_index35_6=new_index35_6, new_alt_index35_6=new_alt_index35_6)
# data_model35_6 = np.load('/Users/mtownsend/Documents/LRG_Data/low35_model6_output-EDR.npz')
# data_model35_6 = np.load('/Users/mtownsend/Documents/LRG_Data/mid35_model6_output-EDR.npz')
data_model35_6 = np.load('/Users/mtownsend/Documents/LRG_Data/high35_model6_output-EDR.npz')
rzNew35_6 = data_model35_6['new_rz35_6']
grNew35_6 = data_model35_6['new_gr35_6']
zmagNew35_6 = data_model35_6['new_zmag35_6']

print(len(rzNew35_6))
print(len(grNew35_6))
print(len(zmagNew35_6))

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model7_output-EDR.npz', new_rz35_7=new_rz35_7, new_gr35_7=new_gr35_7, new_zmag35_7=new_zmag35_7, new_index35_7=new_index35_7, new_alt_index35_7=new_alt_index35_7)
# data_model35_7 = np.load('/Users/mtownsend/Documents/LRG_Data/low35_model7_output-EDR.npz')
# data_model35_7 = np.load('/Users/mtownsend/Documents/LRG_Data/mid35_model7_output-EDR.npz')
data_model35_7 = np.load('/Users/mtownsend/Documents/LRG_Data/high35_model7_output-EDR.npz')
rzNew35_7 = data_model35_7['new_rz35_7']
grNew35_7 = data_model35_7['new_gr35_7']
zmagNew35_7 = data_model35_7['new_zmag35_7']

print(len(rzNew35_7))
print(len(grNew35_7))
print(len(zmagNew35_7))

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model8_output-EDR.npz', new_rz35_8=new_rz35_8, new_gr35_8=new_gr35_8, new_zmag35_8=new_zmag35_8, new_index35_8=new_index35_8, new_alt_index35_8=new_alt_index35_8)
# data_model35_8 = np.load('/Users/mtownsend/Documents/LRG_Data/low35_model8_output-EDR.npz')
# data_model35_8 = np.load('/Users/mtownsend/Documents/LRG_Data/mid35_model8_output-EDR.npz')
data_model35_8 = np.load('/Users/mtownsend/Documents/LRG_Data/high35_model8_output-EDR.npz')
rzNew35_8 = data_model35_8['new_rz35_8']
grNew35_8 = data_model35_8['new_gr35_8']
zmagNew35_8 = data_model35_8['new_zmag35_8']

print(len(rzNew35_8))
print(len(grNew35_8))
print(len(zmagNew35_8))
# Out:
# 862
# 862
# 862
# 862
# 862
# 862
# 862
# 862
# 862
# 862
# 862
# 862
# 862
# 862
# 862
# 862
# 862
# 862
# 862
# 862
# 862
# 862
# 862
# 862

# %%
# read in models

# 0.35 < z < 0.5

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model1_output-EDR.npz', new_rz35_1=new_rz35_1, new_gr35_1=new_gr35_1, new_zmag35_1=new_zmag35_1, new_index35_1=new_index35_1, new_alt_index35_1=new_alt_index35_1)
data_model05_1 = np.load('/Users/mtownsend/Documents/LRG_Data/mid05_model1_output-EDR.npz')
# data_model05_1 = np.load('/Users/mtownsend/Documents/LRG_Data/high05_model1_output-EDR.npz')
rzNew05_1 = data_model05_1['new_rz35_1']
grNew05_1 = data_model05_1['new_gr35_1']
zmagNew05_1 = data_model05_1['new_zmag35_1']

print(len(rzNew05_1))
print(len(grNew05_1))
print(len(zmagNew05_1))

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model2_output-EDR.npz', new_rz35_2=new_rz35_2, new_gr35_2=new_gr35_2, new_zmag35_2=new_zmag35_2, new_index35_2=new_index35_2, new_alt_index35_2=new_alt_index35_2)
# data_model05_2 = np.load('/Users/mtownsend/Documents/LRG_Data/mid05_model2_output-EDR.npz')
data_model05_2 = np.load('/Users/mtownsend/Documents/LRG_Data/high05_model2_output-EDR.npz')
rzNew05_2 = data_model05_2['new_rz35_2']
grNew05_2 = data_model05_2['new_gr35_2']
zmagNew05_2 = data_model05_2['new_zmag35_2']

print(len(rzNew05_2))
print(len(grNew05_2))
print(len(zmagNew05_2))

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model3_output-EDR.npz', new_rz35_3=new_rz35_3, new_gr35_3=new_gr35_3, new_zmag35_3=new_zmag35_3, new_index35_3=new_index35_3, new_alt_index35_3=new_alt_index35_3)
# data_model05_3 = np.load('/Users/mtownsend/Documents/LRG_Data/mid05_model3_output-EDR.npz')
data_model05_3 = np.load('/Users/mtownsend/Documents/LRG_Data/high05_model3_output-EDR.npz')
rzNew05_3 = data_model05_3['new_rz35_3']
grNew05_3 = data_model05_3['new_gr35_3']
zmagNew05_3 = data_model05_3['new_zmag35_3']

print(len(rzNew05_3))
print(len(grNew05_3))
print(len(zmagNew05_3))

# np.savez('/Users/mtownsend/Documents/LRG_Data/low35_model4_output-EDR.npz', new_rz35_4=new_rz35_4, new_gr35_4=new_gr35_4, new_zmag35_4=new_zmag35_4, new_index35_4=new_index35_4, new_alt_index35_4=new_alt_index35_4)
# data_model05_4 = np.load('/Users/mtownsend/Documents/LRG_Data/mid05_model4_output-EDR.npz')
data_model05_4 = np.load('/Users/mtownsend/Documents/LRG_Data/high05_model4_output-EDR.npz')
rzNew05_4 = data_model05_4['new_rz35_4']
grNew05_4 = data_model05_4['new_gr35_4']
zmagNew05_4 = data_model05_4['new_zmag35_4']

print(len(rzNew05_4))
print(len(grNew05_4))
print(len(zmagNew05_4))

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model5_output-EDR.npz', new_rz35_5=new_rz35_5, new_gr35_5=new_gr35_5, new_zmag35_5=new_zmag35_5, new_index35_5=new_index35_5, new_alt_index35_5=new_alt_index35_5)
# data_model05_5 = np.load('/Users/mtownsend/Documents/LRG_Data/mid05_model5_output-EDR.npz')
data_model05_5 = np.load('/Users/mtownsend/Documents/LRG_Data/high05_model5_output-EDR.npz')
rzNew05_5 = data_model05_5['new_rz35_5']
grNew05_5 = data_model05_5['new_gr35_5']
zmagNew05_5 = data_model05_5['new_zmag35_5']

print(len(rzNew05_5))
print(len(grNew05_5))
print(len(zmagNew05_5))

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model6_output-EDR.npz', new_rz35_6=new_rz35_6, new_gr35_6=new_gr35_6, new_zmag35_6=new_zmag35_6, new_index35_6=new_index35_6, new_alt_index35_6=new_alt_index35_6)
# data_model05_6 = np.load('/Users/mtownsend/Documents/LRG_Data/mid05_model6_output-EDR.npz')
data_model05_6 = np.load('/Users/mtownsend/Documents/LRG_Data/high05_model6_output-EDR.npz')
rzNew05_6 = data_model05_6['new_rz35_6']
grNew05_6 = data_model05_6['new_gr35_6']
zmagNew05_6 = data_model05_6['new_zmag35_6']

print(len(rzNew05_6))
print(len(grNew05_6))
print(len(zmagNew05_6))

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model7_output-EDR.npz', new_rz35_7=new_rz35_7, new_gr35_7=new_gr35_7, new_zmag35_7=new_zmag35_7, new_index35_7=new_index35_7, new_alt_index35_7=new_alt_index35_7)
# data_model05_7 = np.load('/Users/mtownsend/Documents/LRG_Data/mid05_model7_output-EDR.npz')
data_model05_7 = np.load('/Users/mtownsend/Documents/LRG_Data/high05_model7_output-EDR.npz')
rzNew05_7 = data_model05_7['new_rz35_7']
grNew05_7 = data_model05_7['new_gr35_7']
zmagNew05_7 = data_model05_7['new_zmag35_7']

print(len(rzNew05_7))
print(len(grNew05_7))
print(len(zmagNew05_7))

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model8_output-EDR.npz', new_rz35_8=new_rz35_8, new_gr35_8=new_gr35_8, new_zmag35_8=new_zmag35_8, new_index35_8=new_index35_8, new_alt_index35_8=new_alt_index35_8)
# data_model05_8 = np.load('/Users/mtownsend/Documents/LRG_Data/mid05_model8_output-EDR.npz')
data_model05_8 = np.load('/Users/mtownsend/Documents/LRG_Data/high05_model8_output-EDR.npz')
rzNew05_8 = data_model05_8['new_rz35_8']
grNew05_8 = data_model05_8['new_gr35_8']
zmagNew05_8 = data_model05_8['new_zmag35_8']

print(len(rzNew05_8))
print(len(grNew05_8))
print(len(zmagNew05_8))
# Out:
# 3311
# 3311
# 3311

# %%
# read in models

# 0.5 < z < 0.65

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model1_output-EDR.npz', new_rz35_1=new_rz35_1, new_gr35_1=new_gr35_1, new_zmag35_1=new_zmag35_1, new_index35_1=new_index35_1, new_alt_index35_1=new_alt_index35_1)
data_model65_1 = np.load('/Users/mtownsend/Documents/LRG_Data/high65_model1_output-EDR.npz')
rzNew65_1 = data_model65_1['new_rz35_1']
grNew65_1 = data_model65_1['new_gr35_1']
zmagNew65_1 = data_model65_1['new_zmag35_1']

print(len(rzNew65_1))
print(len(grNew65_1))
print(len(zmagNew65_1))

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model2_output-EDR.npz', new_rz35_2=new_rz35_2, new_gr35_2=new_gr35_2, new_zmag35_2=new_zmag35_2, new_index35_2=new_index35_2, new_alt_index35_2=new_alt_index35_2)
data_model65_2 = np.load('/Users/mtownsend/Documents/LRG_Data/high65_model2_output-EDR.npz')
rzNew65_2 = data_model65_2['new_rz35_2']
grNew65_2 = data_model65_2['new_gr35_2']
zmagNew65_2 = data_model65_2['new_zmag35_2']

print(len(rzNew65_2))
print(len(grNew65_2))
print(len(zmagNew65_2))

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model3_output-EDR.npz', new_rz35_3=new_rz35_3, new_gr35_3=new_gr35_3, new_zmag35_3=new_zmag35_3, new_index35_3=new_index35_3, new_alt_index35_3=new_alt_index35_3)
data_model65_3 = np.load('/Users/mtownsend/Documents/LRG_Data/high65_model3_output-EDR.npz')
rzNew65_3 = data_model65_3['new_rz35_3']
grNew65_3 = data_model65_3['new_gr35_3']
zmagNew65_3 = data_model65_3['new_zmag35_3']

print(len(rzNew65_3))
print(len(grNew65_3))
print(len(zmagNew65_3))

# np.savez('/Users/mtownsend/Documents/LRG_Data/low35_model4_output-EDR.npz', new_rz35_4=new_rz35_4, new_gr35_4=new_gr35_4, new_zmag35_4=new_zmag35_4, new_index35_4=new_index35_4, new_alt_index35_4=new_alt_index35_4)
data_model65_4 = np.load('/Users/mtownsend/Documents/LRG_Data/high65_model4_output-EDR.npz')
rzNew65_4 = data_model65_4['new_rz35_4']
grNew65_4 = data_model65_4['new_gr35_4']
zmagNew65_4 = data_model65_4['new_zmag35_4']

print(len(rzNew65_4))
print(len(grNew65_4))
print(len(zmagNew65_4))

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model5_output-EDR.npz', new_rz35_5=new_rz35_5, new_gr35_5=new_gr35_5, new_zmag35_5=new_zmag35_5, new_index35_5=new_index35_5, new_alt_index35_5=new_alt_index35_5)
data_model65_5 = np.load('/Users/mtownsend/Documents/LRG_Data/high65_model5_output-EDR.npz')
rzNew65_5 = data_model65_5['new_rz35_5']
grNew65_5 = data_model65_5['new_gr35_5']
zmagNew65_5 = data_model65_5['new_zmag35_5']

print(len(rzNew65_5))
print(len(grNew65_5))
print(len(zmagNew65_5))

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model6_output-EDR.npz', new_rz35_6=new_rz35_6, new_gr35_6=new_gr35_6, new_zmag35_6=new_zmag35_6, new_index35_6=new_index35_6, new_alt_index35_6=new_alt_index35_6)
data_model65_6 = np.load('/Users/mtownsend/Documents/LRG_Data/high65_model6_output-EDR.npz')
rzNew65_6 = data_model65_6['new_rz35_6']
grNew65_6 = data_model65_6['new_gr35_6']
zmagNew65_6 = data_model65_6['new_zmag35_6']

print(len(rzNew65_6))
print(len(grNew65_6))
print(len(zmagNew65_6))

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model7_output-EDR.npz', new_rz35_7=new_rz35_7, new_gr35_7=new_gr35_7, new_zmag35_7=new_zmag35_7, new_index35_7=new_index35_7, new_alt_index35_7=new_alt_index35_7)
data_model65_7 = np.load('/Users/mtownsend/Documents/LRG_Data/high65_model7_output-EDR.npz')
rzNew65_7 = data_model65_7['new_rz35_7']
grNew65_7 = data_model65_7['new_gr35_7']
zmagNew65_7 = data_model65_7['new_zmag35_7']

print(len(rzNew65_7))
print(len(grNew65_7))
print(len(zmagNew65_7))

# np.savez('/Users/mtownsend/Documents/LRG_Data/high65_model8_output-EDR.npz', new_rz35_8=new_rz35_8, new_gr35_8=new_gr35_8, new_zmag35_8=new_zmag35_8, new_index35_8=new_index35_8, new_alt_index35_8=new_alt_index35_8)
data_model65_8 = np.load('/Users/mtownsend/Documents/LRG_Data/high65_model8_output-EDR.npz')
rzNew65_8 = data_model65_8['new_rz35_8']
grNew65_8 = data_model65_8['new_gr35_8']
zmagNew65_8 = data_model65_8['new_zmag35_8']

print(len(rzNew65_8))
print(len(grNew65_8))
print(len(zmagNew65_8))
# Out:
# 2417
# 2417
# 2417
# 2417
# 2417
# 2417
# 2417
# 2417
# 2417
# 2417
# 2417
# 2417
# 2417
# 2417
# 2417
# 2417
# 2417
# 2417
# 2417
# 2417
# 2417
# 2417
# 2417
# 2417

# %%
rz_edges = np.array([-1.8027077, -1.5527076721191406, -1.3027076721191406, -1.0527076721191406, -0.8027076721191406, -0.5527076721191406, -0.3027076721191406, -0.052707672119140625, 0.19729232788085938, 0.4472923278808594, 0.6972923278808594, 0.9472923278808594, 1.1972923278808594, 1.4472923278808594, 1.6972923278808594, 1.9472923278808594, 2.1972923278808594, 2.4472923278808594, 2.6972923278808594, 2.9472923278808594, 3.1972923278808594, 3.4472923278808594, 3.6972923278808594, 3.9472923278808594, 4.197292327880859, 4.447292327880859, 4.697292327880859, 4.947292327880859, 5.197292327880859, 5.447292327880859, 5.697292327880859, 5.947292327880859, 6.197292327880859, 6.447292327880859, 6.697292327880859, 6.947292327880859, 7.197292327880859, 7.447292327880859, 7.697292327880859, 7.947292327880859, 8.19729232788086, 8.44729232788086, 8.69729232788086, 8.94729232788086, 9.19729232788086, 9.44729232788086, 9.69729232788086, 9.94729232788086, 10.19729232788086, 10.44729232788086])
gr_edges = np.array([-6.5846786, -6.234678649902344, -5.8846786499023445, -5.534678649902345, -5.184678649902345, -4.8346786499023455, -4.484678649902346, -4.134678649902346, -3.784678649902346, -3.434678649902346, -3.084678649902346, -2.734678649902346, -2.384678649902346, -2.0346786499023457, -1.6846786499023456, -1.3346786499023455, -0.9846786499023455, -0.6346786499023456, -0.2846786499023456, 0.06532135009765438, 0.41532135009765436, 0.7653213500976543, 1.1153213500976542, 1.4653213500976543, 1.8153213500976544, 2.1653213500976545, 2.5153213500976546, 2.8653213500976547, 3.2153213500976547, 3.565321350097655, 3.915321350097655, 4.265321350097655, 4.615321350097655, 4.965321350097654, 5.315321350097654, 5.665321350097654, 6.015321350097653, 6.365321350097653, 6.7153213500976525, 7.065321350097652, 7.415321350097652, 7.7653213500976515, 8.115321350097652, 8.465321350097652, 8.815321350097651, 9.165321350097651, 9.51532135009765, 9.86532135009765, 10.21532135009765, 10.56532135009765])

zmaginit = 13.
zmagfin = 23.
interval = 0.2
zmag_num = (zmagfin-zmaginit)/interval
zmag_edges, step = np.linspace(zmaginit, zmagfin, num=int(zmag_num), retstep=True)
print(type(zmag_edges))
print(zmag_edges)
# Out:
# <class 'numpy.ndarray'>
# [13.         13.20408163 13.40816327 13.6122449  13.81632653 14.02040816
#  14.2244898  14.42857143 14.63265306 14.83673469 15.04081633 15.24489796
#  15.44897959 15.65306122 15.85714286 16.06122449 16.26530612 16.46938776
#  16.67346939 16.87755102 17.08163265 17.28571429 17.48979592 17.69387755
#  17.89795918 18.10204082 18.30612245 18.51020408 18.71428571 18.91836735
#  19.12244898 19.32653061 19.53061224 19.73469388 19.93877551 20.14285714
#  20.34693878 20.55102041 20.75510204 20.95918367 21.16326531 21.36734694
#  21.57142857 21.7755102  21.97959184 22.18367347 22.3877551  22.59183673
#  22.79591837 23.        ]

# %%
# create new 3D histograms with new_rz, new_gr, and new_zmag
test_model = []
for i in range(len(rzNew35_1)):
    if len(rzNew35_1[i]) == 0:
        hist3d = np.zeros((len(rz_edges) - 1, len(gr_edges) - 1, len(zmag_edges - 1)))
        # hist2d = np.zeros((len(xedges) - 1, len(yedges) - 1))
        test_model.append(hist3d)
    else:

        # hist2d, x_notuse, y_notuse = np.histogram2d(mag[index1[i]], color[index1[i]], bins=(xedges, yedges), normed=False)
        # hist3d, edges_nouse = np.histogramdd((color1[index[i]], mag[index[i]], color2[index[i]]), bins=(edges[0], edges[1], edges[2]),
        #                                             density=False)
        hist3d, edges_nouse = np.histogramdd((rzNew35_1[i], grNew35_1[i], zmagNew35_1[i]), bins=(rz_edges, gr_edges, zmag_edges), density=False)
        test_model.append(hist3d)
        
print(len(test_model))
print(np.asarray(test_model).shape)
# Out:
# 862
# (862, 49, 49, 49)

# %%
# save/read in test models

# np.savez('/Users/mtownsend/Documents/LRG_Data/models/high_model1_near35-EDR.npz', test_model1=test_model)
data1_35 = np.load('/Users/mtownsend/Documents/LRG_Data/models/high_model1_near65-EDR.npz')
model35_1 = data1_35['test_model1']

print(np.asarray(model35_1).shape)

# np.savez('/Users/mtownsend/Documents/LRG_Data/models/high_model2_near35-EDR.npz', test_model2=test_model)
data2_35 = np.load('/Users/mtownsend/Documents/LRG_Data/models/high_model2_near65-EDR.npz')
model35_2 = data2_35['test_model2']

print(np.asarray(model35_2).shape)

# np.savez('/Users/mtownsend/Documents/LRG_Data/models/high_model3_near35-EDR.npz', test_model3=test_model)
data3_35 = np.load('/Users/mtownsend/Documents/LRG_Data/models/high_model3_near65-EDR.npz')
model35_3 = data3_35['test_model3']

print(np.asarray(model35_3).shape)

# np.savez('/Users/mtownsend/Documents/LRG_Data/models/high_model4_near35-EDR.npz', test_model4=test_model)
data4_35 = np.load('/Users/mtownsend/Documents/LRG_Data/models/high_model4_near65-EDR.npz')
model35_4 = data4_35['test_model4']

print(np.asarray(model35_4).shape)

# np.savez('/Users/mtownsend/Documents/LRG_Data/models/high_model5_near35-EDR.npz', test_model5=test_model)
data5_35 = np.load('/Users/mtownsend/Documents/LRG_Data/models/high_model5_near65-EDR.npz')
model35_5 = data5_35['test_model5']

print(np.asarray(model35_5).shape)

# np.savez('/Users/mtownsend/Documents/LRG_Data/models/high_model6_near35-EDR.npz', test_model6=test_model)
data6_35 = np.load('/Users/mtownsend/Documents/LRG_Data/models/high_model6_near65-EDR.npz')
model35_6 = data6_35['test_model6']

print(np.asarray(model35_6).shape)

# np.savez('/Users/mtownsend/Documents/LRG_Data/models/high_model7_near35-EDR.npz', test_model7=test_model)
data7_35 = np.load('/Users/mtownsend/Documents/LRG_Data/models/high_model7_near65-EDR.npz')
model35_7 = data7_35['test_model7']

print(np.asarray(model35_7).shape)

# np.savez('/Users/mtownsend/Documents/LRG_Data/models/high_model8_near35-EDR.npz', test_model8=test_model)
data8_35 = np.load('/Users/mtownsend/Documents/LRG_Data/models/high_model8_near65-EDR.npz')
model35_8 = data8_35['test_model8']

print(np.asarray(model35_8).shape)
# Out:
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)

# %%
# read in relevant Nbkg

null_Nbkg = np.load('/Users/mtownsend/Documents/LRG_Data/null_Nbkg_high-EDR.npz')
Nbkg_total = null_Nbkg['Nbkg_total']
Nbkg35 = null_Nbkg['data_Nbkg35']
Nbkg05 = null_Nbkg['data_Nbkg05']
Nbkg65 = null_Nbkg['data_Nbkg65']

print(Nbkg35.shape)
print(Nbkg05.shape)
print(Nbkg65.shape)
# Out:
# (862, 49, 49, 49)
# (1721, 49, 49, 49)
# (2417, 49, 49, 49)

# %%
# calculate Nsat for test model

# high_Nsat35_mod1 = np.array(model35_1) - np.array(Nbkg35)
# high_Nsat35_mod2 = np.array(model35_2) - np.array(Nbkg35)
# high_Nsat35_mod3 = np.array(model35_3) - np.array(Nbkg35)
# high_Nsat35_mod4 = np.array(model35_4) - np.array(Nbkg35)
# high_Nsat35_mod5 = np.array(model35_5) - np.array(Nbkg35)
# high_Nsat35_mod6 = np.array(model35_6) - np.array(Nbkg35)
# high_Nsat35_mod7 = np.array(model35_7) - np.array(Nbkg35)
# high_Nsat35_mod8 = np.array(model35_8) - np.array(Nbkg35)


# high_Nsat05_mod1 = np.array(model35_1) - np.array(Nbkg05)
# high_Nsat05_mod2 = np.array(model35_2) - np.array(Nbkg05)
# high_Nsat05_mod3 = np.array(model35_3) - np.array(Nbkg05)
# high_Nsat05_mod4 = np.array(model35_4) - np.array(Nbkg05)
# high_Nsat05_mod5 = np.array(model35_5) - np.array(Nbkg05)
# high_Nsat05_mod6 = np.array(model35_6) - np.array(Nbkg05)
# high_Nsat05_mod7 = np.array(model35_7) - np.array(Nbkg05)
# high_Nsat05_mod8 = np.array(model35_8) - np.array(Nbkg05)


high_Nsat65_mod1 = np.array(model35_1) - np.array(Nbkg65)
high_Nsat65_mod2 = np.array(model35_2) - np.array(Nbkg65)
high_Nsat65_mod3 = np.array(model35_3) - np.array(Nbkg65)
high_Nsat65_mod4 = np.array(model35_4) - np.array(Nbkg65)
high_Nsat65_mod5 = np.array(model35_5) - np.array(Nbkg65)
high_Nsat65_mod6 = np.array(model35_6) - np.array(Nbkg65)
high_Nsat65_mod7 = np.array(model35_7) - np.array(Nbkg65)
high_Nsat65_mod8 = np.array(model35_8) - np.array(Nbkg65)

# %%
# read in selection matrices

# # lowz
# smatrix_low = np.load('/Users/mtownsend/Desktop/lowz_smatrix-1matrices-EDR.npz')
# low_smatrix = smatrix_low['smatrix']
# smatrix_low35 = low_smatrix[0]
# print(smatrix_low35.shape)

# print()
# print()

# # midz
# smatrix_mid = np.load('/Users/mtownsend/Desktop/midz_smatrix-2matrices-EDR.npz')
# mid_smatrix = smatrix_mid['smatrix']
# smatrix_mid35 = mid_smatrix[0]
# smatrix_mid05 = mid_smatrix[1]
# print(smatrix_mid35.shape)
# print(smatrix_mid05.shape)

# print()
# print()

# highz
smatrix_high = np.load('/Users/mtownsend/Desktop/highz_smatrix-3matrices-EDR.npz')
high_smatrix = smatrix_high['smatrix']
smatrix_high35 = high_smatrix[0]
smatrix_high05 = high_smatrix[1]
smatrix_high65 = high_smatrix[2]
print(smatrix_high35.shape)
print(smatrix_high05.shape)
print(smatrix_high65.shape)
# Out:
# (49, 49, 49)
# (49, 49, 49)
# (49, 49, 49)

# %%
# apply masks

# null Nsat

# masked_Nsat_null = []
# for i in range(len(null_Nsat)):
#     masked_Nsat_null.append(null_Nsat[i] * smatrix_low35)
    
# print(np.asarray(masked_Nsat_null).shape)


# # lowz
# masked_Nsat_low35_mod1 = []
# for i in range(len(low_Nsat35_mod1)):
#     masked_Nsat_low35_mod1.append(low_Nsat35_mod1[i] * smatrix_low35)

# print(np.asarray(masked_Nsat_low35_mod1).shape)

# masked_Nsat_low35_mod2 = []
# for i in range(len(low_Nsat35_mod2)):
#     masked_Nsat_low35_mod2.append(low_Nsat35_mod2[i] * smatrix_low35)

# print(np.asarray(masked_Nsat_low35_mod2).shape)

# masked_Nsat_low35_mod3 = []
# for i in range(len(low_Nsat35_mod3)):
#     masked_Nsat_low35_mod3.append(low_Nsat35_mod3[i] * smatrix_low35)

# print(np.asarray(masked_Nsat_low35_mod3).shape)

# masked_Nsat_low35_mod4 = []
# for i in range(len(low_Nsat35_mod4)):
#     masked_Nsat_low35_mod4.append(low_Nsat35_mod4[i] * smatrix_low35)

# print(np.asarray(masked_Nsat_low35_mod4).shape)

# masked_Nsat_low35_mod5 = []
# for i in range(len(low_Nsat35_mod5)):
#     masked_Nsat_low35_mod5.append(low_Nsat35_mod5[i] * smatrix_low35)

# print(np.asarray(masked_Nsat_low35_mod5).shape)

# masked_Nsat_low35_mod6 = []
# for i in range(len(low_Nsat35_mod6)):
#     masked_Nsat_low35_mod6.append(low_Nsat35_mod6[i] * smatrix_low35)

# print(np.asarray(masked_Nsat_low35_mod6).shape)

# masked_Nsat_low35_mod7 = []
# for i in range(len(low_Nsat35_mod7)):
#     masked_Nsat_low35_mod7.append(low_Nsat35_mod7[i] * smatrix_low35)

# print(np.asarray(masked_Nsat_low35_mod7).shape)

# masked_Nsat_low35_mod8 = []
# for i in range(len(low_Nsat35_mod8)):
#     masked_Nsat_low35_mod8.append(low_Nsat35_mod8[i] * smatrix_low35)

# print(np.asarray(masked_Nsat_low35_mod8).shape)




# mid35

# masked_Nsat_mid35_mod1 = []
# for i in range(len(mid_Nsat35_mod1)):
#     masked_Nsat_mid35_mod1.append(mid_Nsat35_mod1[i] * smatrix_mid35)
    
# print(np.asarray(masked_Nsat_mid35_mod1).shape)

# masked_Nsat_mid35_mod2 = []
# for i in range(len(mid_Nsat35_mod2)):
#     masked_Nsat_mid35_mod2.append(mid_Nsat35_mod2[i] * smatrix_mid35)
    
# print(np.asarray(masked_Nsat_mid35_mod2).shape)

# masked_Nsat_mid35_mod3 = []
# for i in range(len(mid_Nsat35_mod3)):
#     masked_Nsat_mid35_mod3.append(mid_Nsat35_mod3[i] * smatrix_mid35)
    
# print(np.asarray(masked_Nsat_mid35_mod3).shape)

# masked_Nsat_mid35_mod4 = []
# for i in range(len(mid_Nsat35_mod4)):
#     masked_Nsat_mid35_mod4.append(mid_Nsat35_mod4[i] * smatrix_mid35)
    
# print(np.asarray(masked_Nsat_mid35_mod4).shape)

# masked_Nsat_mid35_mod5 = []
# for i in range(len(mid_Nsat35_mod5)):
#     masked_Nsat_mid35_mod5.append(mid_Nsat35_mod5[i] * smatrix_mid35)
    
# print(np.asarray(masked_Nsat_mid35_mod5).shape)

# masked_Nsat_mid35_mod6 = []
# for i in range(len(mid_Nsat35_mod6)):
#     masked_Nsat_mid35_mod6.append(mid_Nsat35_mod6[i] * smatrix_mid35)
    
# print(np.asarray(masked_Nsat_mid35_mod6).shape)

# masked_Nsat_mid35_mod7 = []
# for i in range(len(mid_Nsat35_mod7)):
#     masked_Nsat_mid35_mod7.append(mid_Nsat35_mod7[i] * smatrix_mid35)
    
# print(np.asarray(masked_Nsat_mid35_mod7).shape)

# masked_Nsat_mid35_mod8 = []
# for i in range(len(mid_Nsat35_mod8)):
#     masked_Nsat_mid35_mod8.append(mid_Nsat35_mod8[i] * smatrix_mid35)
    
# print(np.asarray(masked_Nsat_mid35_mod8).shape)

# # mid05
    
# masked_Nsat_mid05_mod1 = []
# for i in range(len(mid_Nsat05_mod1)):
#     masked_Nsat_mid05_mod1.append(mid_Nsat05_mod1[i] * smatrix_mid05)
    
# print(np.asarray(masked_Nsat_mid05_mod1).shape)

# masked_Nsat_mid05_mod2 = []
# for i in range(len(mid_Nsat05_mod2)):
#     masked_Nsat_mid05_mod2.append(mid_Nsat05_mod2[i] * smatrix_mid05)
    
# print(np.asarray(masked_Nsat_mid05_mod2).shape)

# masked_Nsat_mid05_mod3 = []
# for i in range(len(mid_Nsat05_mod3)):
#     masked_Nsat_mid05_mod3.append(mid_Nsat05_mod3[i] * smatrix_mid05)
    
# print(np.asarray(masked_Nsat_mid05_mod3).shape)

# masked_Nsat_mid05_mod4 = []
# for i in range(len(mid_Nsat05_mod4)):
#     masked_Nsat_mid05_mod4.append(mid_Nsat05_mod4[i] * smatrix_mid05)
    
# print(np.asarray(masked_Nsat_mid05_mod4).shape)

# masked_Nsat_mid05_mod5 = []
# for i in range(len(mid_Nsat05_mod5)):
#     masked_Nsat_mid05_mod5.append(mid_Nsat05_mod5[i] * smatrix_mid05)
    
# print(np.asarray(masked_Nsat_mid05_mod5).shape)

# masked_Nsat_mid05_mod6 = []
# for i in range(len(mid_Nsat05_mod6)):
#     masked_Nsat_mid05_mod6.append(mid_Nsat05_mod6[i] * smatrix_mid05)
    
# print(np.asarray(masked_Nsat_mid05_mod6).shape)

# masked_Nsat_mid05_mod7 = []
# for i in range(len(mid_Nsat05_mod7)):
#     masked_Nsat_mid05_mod7.append(mid_Nsat05_mod7[i] * smatrix_mid05)
    
# print(np.asarray(masked_Nsat_mid05_mod7).shape)

# masked_Nsat_mid05_mod8 = []
# for i in range(len(mid_Nsat05_mod8)):
#     masked_Nsat_mid05_mod8.append(mid_Nsat05_mod8[i] * smatrix_mid05)
    
# print(np.asarray(masked_Nsat_mid05_mod8).shape)




# # high35

# masked_Nsat_high35_mod1 = []
# for i in range(len(high_Nsat35_mod1)):
#     masked_Nsat_high35_mod1.append(high_Nsat35_mod1[i] * smatrix_high35)
    
# print(np.asarray(masked_Nsat_high35_mod1).shape)

# masked_Nsat_high35_mod2 = []
# for i in range(len(high_Nsat35_mod2)):
#     masked_Nsat_high35_mod2.append(high_Nsat35_mod2[i] * smatrix_high35)
    
# print(np.asarray(masked_Nsat_high35_mod2).shape)

# masked_Nsat_high35_mod3 = []
# for i in range(len(high_Nsat35_mod3)):
#     masked_Nsat_high35_mod3.append(high_Nsat35_mod3[i] * smatrix_high35)
    
# print(np.asarray(masked_Nsat_high35_mod3).shape)

# masked_Nsat_high35_mod4 = []
# for i in range(len(high_Nsat35_mod4)):
#     masked_Nsat_high35_mod4.append(high_Nsat35_mod4[i] * smatrix_high35)
    
# print(np.asarray(masked_Nsat_high35_mod4).shape)

# masked_Nsat_high35_mod5 = []
# for i in range(len(high_Nsat35_mod5)):
#     masked_Nsat_high35_mod5.append(high_Nsat35_mod5[i] * smatrix_high35)
    
# print(np.asarray(masked_Nsat_high35_mod5).shape)

# masked_Nsat_high35_mod6 = []
# for i in range(len(high_Nsat35_mod6)):
#     masked_Nsat_high35_mod6.append(high_Nsat35_mod6[i] * smatrix_high35)
    
# print(np.asarray(masked_Nsat_high35_mod6).shape)

# masked_Nsat_high35_mod7 = []
# for i in range(len(high_Nsat35_mod7)):
#     masked_Nsat_high35_mod7.append(high_Nsat35_mod7[i] * smatrix_high35)
    
# print(np.asarray(masked_Nsat_high35_mod7).shape)

# masked_Nsat_high35_mod8 = []
# for i in range(len(high_Nsat35_mod8)):
#     masked_Nsat_high35_mod8.append(high_Nsat35_mod8[i] * smatrix_high35)
    
# print(np.asarray(masked_Nsat_high35_mod8).shape)


# # high05

# masked_Nsat_high05_mod1 = []
# for i in range(len(high_Nsat05_mod1)):
#     masked_Nsat_high05_mod1.append(high_Nsat05_mod1[i] * smatrix_high05)
    
# print(np.asarray(masked_Nsat_high05_mod1).shape)

# masked_Nsat_high05_mod2 = []
# for i in range(len(high_Nsat05_mod2)):
#     masked_Nsat_high05_mod2.append(high_Nsat05_mod2[i] * smatrix_high05)
    
# print(np.asarray(masked_Nsat_high05_mod2).shape)

# masked_Nsat_high05_mod3 = []
# for i in range(len(high_Nsat05_mod3)):
#     masked_Nsat_high05_mod3.append(high_Nsat05_mod3[i] * smatrix_high05)
    
# print(np.asarray(masked_Nsat_high05_mod3).shape)

# masked_Nsat_high05_mod4 = []
# for i in range(len(high_Nsat05_mod4)):
#     masked_Nsat_high05_mod4.append(high_Nsat05_mod4[i] * smatrix_high05)
    
# print(np.asarray(masked_Nsat_high05_mod4).shape)

# masked_Nsat_high05_mod5 = []
# for i in range(len(high_Nsat05_mod5)):
#     masked_Nsat_high05_mod5.append(high_Nsat05_mod5[i] * smatrix_high05)
    
# print(np.asarray(masked_Nsat_high05_mod5).shape)

# masked_Nsat_high05_mod6 = []
# for i in range(len(high_Nsat05_mod6)):
#     masked_Nsat_high05_mod6.append(high_Nsat05_mod6[i] * smatrix_high05)
    
# print(np.asarray(masked_Nsat_high05_mod6).shape)

# masked_Nsat_high05_mod7 = []
# for i in range(len(high_Nsat05_mod7)):
#     masked_Nsat_high05_mod7.append(high_Nsat05_mod7[i] * smatrix_high05)
    
# print(np.asarray(masked_Nsat_high05_mod7).shape)

# masked_Nsat_high05_mod8 = []
# for i in range(len(high_Nsat05_mod8)):
#     masked_Nsat_high05_mod8.append(high_Nsat05_mod8[i] * smatrix_high05)
    
# print(np.asarray(masked_Nsat_high05_mod8).shape)



# high65

masked_Nsat_high65_mod1 = []
for i in range(len(high_Nsat65_mod1)):
    masked_Nsat_high65_mod1.append(high_Nsat65_mod1[i] * smatrix_high65)
    
print(np.asarray(masked_Nsat_high65_mod1).shape)

masked_Nsat_high65_mod2 = []
for i in range(len(high_Nsat65_mod2)):
    masked_Nsat_high65_mod2.append(high_Nsat65_mod2[i] * smatrix_high65)
    
print(np.asarray(masked_Nsat_high65_mod2).shape)

masked_Nsat_high65_mod3 = []
for i in range(len(high_Nsat65_mod3)):
    masked_Nsat_high65_mod3.append(high_Nsat65_mod3[i] * smatrix_high65)
    
print(np.asarray(masked_Nsat_high65_mod3).shape)

masked_Nsat_high65_mod4 = []
for i in range(len(high_Nsat65_mod4)):
    masked_Nsat_high65_mod4.append(high_Nsat65_mod4[i] * smatrix_high65)
    
print(np.asarray(masked_Nsat_high65_mod4).shape)

masked_Nsat_high65_mod5 = []
for i in range(len(high_Nsat65_mod5)):
    masked_Nsat_high65_mod5.append(high_Nsat65_mod5[i] * smatrix_high65)
    
print(np.asarray(masked_Nsat_high65_mod5).shape)

masked_Nsat_high65_mod6 = []
for i in range(len(high_Nsat65_mod6)):
    masked_Nsat_high65_mod6.append(high_Nsat65_mod6[i] * smatrix_high65)
    
print(np.asarray(masked_Nsat_high65_mod6).shape)

masked_Nsat_high65_mod7 = []
for i in range(len(high_Nsat65_mod7)):
    masked_Nsat_high65_mod7.append(high_Nsat65_mod7[i] * smatrix_high65)
    
print(np.asarray(masked_Nsat_high65_mod7).shape)

masked_Nsat_high65_mod8 = []
for i in range(len(high_Nsat65_mod8)):
    masked_Nsat_high65_mod8.append(high_Nsat65_mod8[i] * smatrix_high65)
    
print(np.asarray(masked_Nsat_high65_mod8).shape)
# Out:
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)

# %%
# save masked model Nsat


np.savez('/Users/mtownsend/Documents/LRG_Data/models/high_model1_Nsat65-masked-EDR.npz', masked_Nsat_high65_mod1=masked_Nsat_high65_mod1)
data_mid35_1 = np.load('/Users/mtownsend/Documents/LRG_Data/models/high_model1_Nsat65-masked-EDR.npz')
masked_Nsat35_1 = data_mid35_1['masked_Nsat_high65_mod1']

print(masked_Nsat35_1.shape)

np.savez('/Users/mtownsend/Documents/LRG_Data/models/high_model2_Nsat65-masked-EDR.npz', masked_Nsat_high65_mod2=masked_Nsat_high65_mod2)
data_mid35_2 = np.load('/Users/mtownsend/Documents/LRG_Data/models/high_model2_Nsat65-masked-EDR.npz')
masked_Nsat35_2 = data_mid35_2['masked_Nsat_high65_mod2']

print(masked_Nsat35_2.shape)

np.savez('/Users/mtownsend/Documents/LRG_Data/models/high_model3_Nsat65-masked-EDR.npz', masked_Nsat_high65_mod3=masked_Nsat_high65_mod3)
data_mid35_3 = np.load('/Users/mtownsend/Documents/LRG_Data/models/high_model3_Nsat65-masked-EDR.npz')
masked_Nsat35_3 = data_mid35_3['masked_Nsat_high65_mod3']

print(masked_Nsat35_3.shape)

np.savez('/Users/mtownsend/Documents/LRG_Data/models/high_model4_Nsat65-masked-EDR.npz', masked_Nsat_high65_mod4=masked_Nsat_high65_mod4)
data_mid35_4 = np.load('/Users/mtownsend/Documents/LRG_Data/models/high_model4_Nsat65-masked-EDR.npz')
masked_Nsat35_4 = data_mid35_4['masked_Nsat_high65_mod4']

print(masked_Nsat35_4.shape)

np.savez('/Users/mtownsend/Documents/LRG_Data/models/high_model5_Nsat65-masked-EDR.npz', masked_Nsat_high65_mod5=masked_Nsat_high65_mod5)
data_mid35_5 = np.load('/Users/mtownsend/Documents/LRG_Data/models/high_model5_Nsat65-masked-EDR.npz')
masked_Nsat35_5 = data_mid35_5['masked_Nsat_high65_mod5']

print(masked_Nsat35_5.shape)

np.savez('/Users/mtownsend/Documents/LRG_Data/models/high_model6_Nsat65-masked-EDR.npz', masked_Nsat_high65_mod6=masked_Nsat_high65_mod6)
data_mid35_6 = np.load('/Users/mtownsend/Documents/LRG_Data/models/high_model6_Nsat65-masked-EDR.npz')
masked_Nsat35_6 = data_mid35_6['masked_Nsat_high65_mod6']

print(masked_Nsat35_6.shape)

np.savez('/Users/mtownsend/Documents/LRG_Data/models/high_model7_Nsat65-masked-EDR.npz', masked_Nsat_high65_mod7=masked_Nsat_high65_mod7)
data_mid35_7 = np.load('/Users/mtownsend/Documents/LRG_Data/models/high_model7_Nsat65-masked-EDR.npz')
masked_Nsat35_7 = data_mid35_7['masked_Nsat_high65_mod7']

print(masked_Nsat35_7.shape)

np.savez('/Users/mtownsend/Documents/LRG_Data/models/high_model8_Nsat65-masked-EDR.npz', masked_Nsat_high65_mod8=masked_Nsat_high65_mod8)
data_mid35_8 = np.load('/Users/mtownsend/Documents/LRG_Data/models/high_model8_Nsat65-masked-EDR.npz')
masked_Nsat35_8 = data_mid35_8['masked_Nsat_high65_mod8']

print(masked_Nsat35_8.shape)
# Out:
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)
# (2417, 49, 49, 49)

# %%
# Now move on to model_comparison. Compares model Nsat to null and data.
